# %% [markdown]
# # Exercise 4 (Sensitivity analysis of a dynamical model for cellular metabolism)
#
# Glucose is a fundamental constituent of cellular metabolism, serving as a primary energy source and precursor for biosynthetic processes through pathways such as glycolysis, the citric acid cycle, and oxidative phosphorylation. Simply put, cells can exploit glucose supplies, available in the surrounding environment, by absorbing and converting them into energy resources stored in the form of ATP (adenosine triphosphate).
#
# The following system of ordinary differential equations describes the relationship between glucose uptake and cellular metabolism over time using the so-called *Michaelis-Menten Kinetics* model,
#
# $$
# \frac{dG}{dt} = -\frac{V_{\max} G}{K_m + G}, \quad
# \frac{dS}{dt} = \frac{V_{\max} G}{K_m + G} - \alpha S, \quad
# \frac{dE}{dt} = \alpha S - \beta E.
# $$
#
# Here,
#
# - $G$ is the extracellular glucose concentration (mmol/L),
# - $S$ is the intracellular substrate concentration (e.g., mmol/L),
# - $E$ is the energy (ATP) concentration inside the cell (e.g., mmol/L),
#
# whereas the model parameters are:
#
# - $V_{\max}$: maximum rate of glucose uptake (mmol/L/hr),
# - $K_m$: Michaelis-Menten constant for glucose uptake (mmol/L),
# - $\alpha$: Rate of ATP production from glucose metabolism (mmol/L/hr per mmol/L substrate),
# - $\beta$: ATP degradation rate (mmol/L/hr).
#
# Given initial conditions and suitable values for the model parameters, one can solve Eq. (8) numerically and thus simulate the dynamics of the system: cf. Figure 4. We refer to the **auxiliary notebook** for a practical demonstration and related code.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import pandas as pd

T = 15 # Final time
z0 = np.array([10.0, 0.0, 0.0]) # Initial condition for z = [G, S, E]

# ODE model
def F(z, Vmax, Km, alpha, beta):
  G, S, E = z
  return np.array([-Vmax*G/(Km+G), Vmax*G/(Km+G)-alpha*S, alpha*S-beta*E])

# ODE simulator
def metabolic(Vmax, Km, alpha, beta):
  solution = solve_ivp(lambda t, z : F(z, Vmax, Km, alpha, beta), t_span = (0, T), y0 = z0, t_eval=np.linspace(0, T, 1000)) # solve dz / dt = f(t, z)
  t = solution.t
  G, S, E = solution.y
  return t, G, S, E

# Example
t, G, S, E = metabolic(5.0, 5.0, 0.2, 0.1)

plt.figure(figsize = (5, 3.5))
plt.plot(t, G, label = 'G - Glucose')
plt.plot(t, S, label = 'S - Substrate')
plt.plot(t, E, label = 'E - Energy (ATP)')
plt.xlabel("Time [hours]")
plt.ylabel("Concentration [mmol/L]")
plt.legend()
plt.title("Simulation for $V_{\\max}=5,K_m=5,\\alpha=0.2,\\beta=0.1$\n")
plt.show()

# %% [markdown]
# Assume that, at time $t = 0$, one has $G = 10$ mmol/L, $S = 0$ mmol/L, and $E = 0$ mmol/L. Set the terminal time to $T = 15h$. We are interested in studying the behavior of the following quantities,
#
# $$
# Y_1 := G(T), \quad Y_2 := \max_{t \in [0,T]} E(t), \quad Y_3 := \min \{t : G(t) = S(t), \, 0 \leq t \leq T\},
# $$
#
# i.e.: the amount of glucose not absorbed and still available outside the cell ($Y_1$), the maximum energy available throughout the process ($Y_2$), the time at which internal and external glucose supplies balance out ($Y_3$). For this analysis, we consider the following ranges for the physical parameters,
#
# $$
# 5 \leq V_{\max}, K_m \leq 10, \quad 0.1 \leq \alpha, \beta \leq 0.5.
# $$

# %% [markdown]
# ### Tasks
#
# **(a)** Quantify the sensitivity of $Y_1$, $Y_2$, and $Y_3$ (separately) with respect to $V_{\max}, K_m, \alpha, \beta$. To this end, estimate Sobol indices (both main and total effects) using Saltelli’s method with $N = 1024$ samples. Are the results interpretable?

# %%
from scipy.stats.qmc import Sobol

def saltelli_ABC(N, p, xmin, xmax):
  """N = sample size.
     p = number of inputs.
     xmin = minimum value of the inputs (either a scalar or an array of scalars).
     xmax = minimum value of the inputs (either a scalar or an array of scalars).

     Returns: A (N x p matrix), B (N x p matrix), C (list of p matrices, all N x p).
  """
  sobol = Sobol(d=2*p, scramble=True)
  AB = sobol.random(N)
  A, B = AB[:, :p]*(xmax-xmin)+xmin, AB[:, p:]*(xmax-xmin)+xmin

  C = [np.zeros((N, p))]*p
  for i in range(p):
    C[i] = B + 0.0
    C[i][:, i] = A[:, i]

  return A, B, C

def saltelli_Si(yA, yB, yC):
  """yA = vector of length N.
     yB = vector of length N.
     yC = list containing p vectors, each of length N

     Returns: Si (list of main effects), STi (list of total effects)
  """
  N, p = len(yA), len(yC)
  Si  = [(yA @ yC[i]/N - yA.mean()**2)/yA.var() for i in range(p)]
  STi = [1.0 - (yB @ yC[i]/N - yA.mean()**2)/yA.var() for i in range(p)]
  return Si, STi

# %%
clamp01 = lambda s: np.minimum(np.maximum(s, 0), 1)

def sobol_indices(model, p, xmin, xmax, N):
  A, B, C = saltelli_ABC(N, p, xmin, xmax)

  yA = model(A)
  yB = model(B)
  yC = [model(Ci) for Ci in C]

  Si, STi = saltelli_Si(yA, yB, yC)

  return clamp01(Si), clamp01(STi)

# %%
# Quantity of interest

# Amount of glucose not absorbed and still available outside the cell
def Y1(t, G, S, E):
  return G[-1]

# Maximum energy available throughout the process
def Y2(t, G, S, E):
  return E.max()

# Time at which internal and external glucose supplies balance out
def Y3(t, G, S, E):
  return t[np.argmin(np.abs(G-S))]

# %%
def GSEqoi(X, QoI):
  nx = len(X)
  output = np.zeros(nx)
  for j in range(nx):
    Vmax, Km, alpha, beta = X[j]
    t, G, S, E = metabolic(Vmax, Km, alpha, beta)
    output[j] = QoI(t, G, S, E)
  return output

# %%
Si, STi = sobol_indices(lambda X: GSEqoi(X, Y1), p = 4, xmin = np.array([5, 5, 0.1, 0.1]), xmax = np.array([10, 10, 0.5, 0.5]), N = 1024)
pd.DataFrame({'Main effect':Si, 'Total effect':STi}, index = ["Vmax", "Km", "alpha", "beta"])
# Out:
#        Main effect  Total effect
# Vmax      0.295630      0.815370
# Km        0.179868      0.691001
# alpha     0.000000      0.015124
# beta      0.000000      0.015125

# %%
Si, STi = sobol_indices(lambda X: GSEqoi(X, Y2), p = 4, xmin = np.array([5, 5, 0.1, 0.1]), xmax = np.array([10, 10, 0.5, 0.5]), N = 1024)
pd.DataFrame({'Main effect':Si, 'Total effect':STi}, index = ["Vmax", "Km", "alpha", "beta"])
# Out:
#        Main effect  Total effect
# Vmax      0.011087      0.015004
# Km        0.005637      0.006773
# alpha     0.328636      0.333451
# beta      0.647910      0.653231

# %%
Si, STi = sobol_indices(lambda X: GSEqoi(X, Y3), p = 4, xmin = np.array([5, 5, 0.1, 0.1]), xmax = np.array([10, 10, 0.5, 0.5]), N = 1024)
pd.DataFrame({'Main effect':Si, 'Total effect':STi}, index = ["Vmax", "Km", "alpha", "beta"])
# Out:
#        Main effect  Total effect
# Vmax      0.017422      0.718424
# Km        0.058689      0.636367
# alpha     0.316763      0.904869
# beta      0.001098      0.000000

# %% [markdown]
# **(b)** Run a convergence analysis to see whether the number of samples used at point (a) suffices.

# %%
# List of sample sizes to test for convergence
sample_sizes = [256, 512, 1024, 2048, 4096]

# Create dictionaries to store Sobol indices for each parameter for each sample size
sobol_main_indices = { 'Vmax': [], 'Km': [], 'alpha': [], 'beta': [] }
sobol_total_indices = { 'Vmax': [], 'Km': [], 'alpha': [], 'beta': [] }

for N in sample_sizes:
    Si, STi = sobol_indices(lambda X: GSEqoi(X, Y1), p=4,
                              xmin=np.array([5, 5, 0.1, 0.1]),
                              xmax=np.array([10, 10, 0.5, 0.5]),
                              N=N)
    # Assuming Si and STi are arrays of length 4 corresponding to [Vmax, Km, alpha, beta]
    sobol_main_indices['Vmax'].append(Si[0])
    sobol_main_indices['Km'].append(Si[1])
    sobol_main_indices['alpha'].append(Si[2])
    sobol_main_indices['beta'].append(Si[3])

    sobol_total_indices['Vmax'].append(STi[0])
    sobol_total_indices['Km'].append(STi[1])
    sobol_total_indices['alpha'].append(STi[2])
    sobol_total_indices['beta'].append(STi[3])

# %%
# Plot the results for each parameter
parameters = ['Vmax', 'Km', 'alpha', 'beta']
plt.figure(figsize=(8, 6))
for param in parameters:
    plt.plot(sample_sizes, sobol_main_indices[param], marker='o', label=f'{param} (Main)')

plt.xlabel('Sample size (N)')
plt.ylabel('Sobol Index')
plt.title('Convergence of Sobol Indices with Increasing Sample Size')
plt.legend()
plt.xscale('log')  # Optional: log-scale for N if sample sizes vary widely
plt.grid(True)
plt.show()

# %%
# Plot the results for each parameter
parameters = ['Vmax', 'Km', 'alpha', 'beta']
plt.figure(figsize=(8, 6))
for param in parameters:
    plt.plot(sample_sizes, sobol_total_indices[param], marker='x', linestyle='--', label=f'{param} (Total)')

plt.xlabel('Sample size (N)')
plt.ylabel('Sobol Index')
plt.title('Convergence of Sobol Indices with Increasing Sample Size')
plt.legend()
plt.xscale('log')  # Optional: log-scale for N if sample sizes vary widely
plt.grid(True)
plt.show()

# %% [markdown]
# Let us focus on the first two quantities of interest. We would like to speed up the sensitivity analysis by introducing a neural network surrogate, formally replacing the ODE solver.
#
# **(c)** Generate $M = 500$ simulations by drawing random values for the model parameters (uniformly in their parameter range). For each simulation, compute the two quantities of interest $Y_1$ and $Y_2$. Train a neural network model $\phi$ to learn the map
#
# $$
# \mathbb{R}^4 \ni [V_{\max}, K_m, \alpha, \beta]^\top \mapsto [\log Y_1, \log Y_2]^\top \in \mathbb{R}^2.
# $$
#
# To this end, split your data and use 300 simulations for optimization, 100 for validation, and 100 for testing.

# %%
import os
import torch
from torch import nn

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
# Generate M = 500 simulations
M = 500
data = np.random.uniform(low = [5, 5, 0.1, 0.1], high = [10, 10, 0.5, 0.5], size = (M, 4))

data = torch.from_numpy(data)
train_set = data[:300]
val_set = data[300:400]
test_set = data[400:]
train_set.shape, val_set.shape, test_set.shape
# Out:
# (torch.Size([300, 4]), torch.Size([100, 4]), torch.Size([100, 4]))

# %%
data
# Out:
# tensor([[7.0297, 6.4897, 0.1078, 0.3239],
#         [8.1844, 6.4135, 0.4405, 0.1185],
#         [8.8469, 5.9491, 0.1812, 0.4198],
#         ...,
#         [7.4218, 7.1357, 0.4441, 0.3191],
#         [9.3384, 8.0976, 0.2751, 0.1312],
#         [9.0573, 5.8169, 0.1001, 0.3077]], dtype=torch.float64)

# %%
# Compute the two qoi Y1 and Y2
logY1_train = torch.log(torch.tensor(GSEqoi(train_set.numpy(), Y1)))
logY2_train = torch.log(torch.tensor(GSEqoi(train_set.numpy(), Y2)))

logY1_val = torch.log(torch.tensor(GSEqoi(val_set.numpy(), Y1)))
logY2_val = torch.log(torch.tensor(GSEqoi(val_set.numpy(), Y2)))

logY1_test = torch.log(torch.tensor(GSEqoi(test_set.numpy(), Y1)))
logY2_test = torch.log(torch.tensor(GSEqoi(test_set.numpy(), Y2)))

# %%
# Build the neural network
class NeuralNetwork(nn.Module):
    def __init__(self, p, n):
        super().__init__()
        self.leaky_relu_stack = nn.Sequential(
            nn.Linear(p, 30),
            nn.ReLU(),
            nn.Linear(30, 30),
            nn.ReLU(),
            nn.Linear(30, n),
        )

    def forward(self, x):
        output = self.leaky_relu_stack(x)
        return output

# %%
p = 4
n = 2
nn_model = NeuralNetwork(p,n).to(device)
print(nn_model)
# Out:
# NeuralNetwork(
#   (leaky_relu_stack): Sequential(
#     (0): Linear(in_features=4, out_features=30, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=30, out_features=30, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=30, out_features=2, bias=True)
#   )
# )

# %%
# Convert data to float tensor
train_set = train_set.float().to(device)
val_set = val_set.float().to(device)
test_set = test_set.float().to(device)

logY1_train = logY1_train.float().to(device)
logY2_train = logY2_train.float().to(device)
logY1_val = logY1_val.float().to(device)
logY2_val = logY2_val.float().to(device)
logY1_test = logY1_test.float().to(device)
logY2_test = logY2_test.float().to(device)

# %%
# Learning rate
learning_rate = 1e-3

# Stack the targets together
train_targets = torch.stack((logY1_train, logY2_train), dim=1)
val_targets = torch.stack((logY1_val, logY2_val), dim=1)
test_targets = torch.stack((logY1_test, logY2_test), dim=1)

# Define loss function
loss_fn = nn.MSELoss()

# Use full-batch gradient descent
optimizer = torch.optim.SGD(nn_model.parameters(), lr=learning_rate)  # Adjust learning rate as needed

# Training loop
train_losses = []
val_losses = []
num_epochs = 1000  # Set the number of epochs
for epoch in range(num_epochs):
    total_train_loss = 0.0
    for i in range(train_set.shape[0]):  # Loop over each sample
        sample = train_set[i].unsqueeze(0)  # Add batch dimension (1,4)
        target = train_targets[i].unsqueeze(0)  # Target shape (1,2)

        # Forward pass
        output = nn_model(sample)

        # Compute loss
        loss = loss_fn(output, target)
        total_train_loss += loss.item()

        # Backward pass & optimization step
        optimizer.zero_grad()  # Clear previous gradients
        loss.backward()        # Compute gradients / Backpropagation
        optimizer.step()       # Update model / Gradient Descent


    # Compute average training loss
    avg_train_loss = total_train_loss / train_set.shape[0]
    train_losses.append(avg_train_loss)


    # Validation: Evaluate on the full validation set
    nn_model.eval()  # Set model to evaluation mode
    with torch.no_grad():  # No need to compute gradients
        val_outputs = nn_model(val_set)
        val_loss = loss_fn(val_outputs, val_targets).item()  # Compute MSE loss
        val_losses.append(val_loss)

    nn_model.train()  # Switch back to training mode

    # Print progress
    print(f"Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.6f}, Val Loss: {val_loss:.6f}")
# Out:
# Epoch [1/1000], Train Loss: 5.332809, Val Loss: 1.563033
# Epoch [2/1000], Train Loss: 1.590423, Val Loss: 1.173666
# Epoch [3/1000], Train Loss: 1.422602, Val Loss: 1.120727
# Epoch [4/1000], Train Loss: 1.288274, Val Loss: 1.066579
# Epoch [5/1000], Train Loss: 1.203303, Val Loss: 1.015630
# Epoch [6/1000], Train Loss: 1.129695, Val Loss: 0.969494
# Epoch [7/1000], Train Loss: 1.057603, Val Loss: 0.930812
# Epoch [8/1000], Train Loss: 1.000962, Val Loss: 0.895460
# Epoch [9/1000], Train Loss: 0.949505, Val Loss: 0.855550
# Epoch [10/1000], Train Loss: 0.899910, Val Loss: 0.817922
# Epoch [11/1000], Train Loss: 0.855266, Val Loss: 0.781802
# Epoch [12/1000], Train Loss: 0.810942, Val Loss: 0.747406
# Epoch [13/1000], Train Loss: 0.766611, Val Loss: 0.714001
# Epoch [14/1000], Train Loss: 0.730210, Val Loss: 0.681548
# Epoch [15/1000], Train Loss: 0.691447, Val Loss: 0.650009
# Epoch [16/1000], Train Loss: 0.655009, Val Loss: 0.617179
# Epoch [17/1000], Train Loss: 0.620408, Val Loss: 0.585958
# Epoch [18/1000], Train Loss: 0.587638, Val Loss: 0.563584
# Epoch [19/1000], Train Loss: 0.557115, Val Loss: 0.534206
# Epoch [20/1000], Train Loss: 0.527861, Val Loss: 0.508056
# Epoch [21/1000], Train Loss: 0.498987, Val Loss: 0.509789
# Epoch [22/1000], Train Loss: 0.475577, Val Loss: 0.465419
# Epoch [23/1000], Train Loss: 0.453064, Val Loss: 0.431646
# Epoch [24/1000], Train Loss: 0.426750, Val Loss: 0.423919
# Epoch [25/1000], Train Loss: 0.409747, Val Loss: 0.398418
# Epoch [26/1000], Train Loss: 0.386144, Val Loss: 0.390665
# Epoch [27/1000], Train Loss: 0.371391, Val Loss: 0.363668
# Epoch [28/1000], Train Loss: 0.351009, Val Loss: 0.361599
# Epoch [29/1000], Train Loss: 0.339220, Val Loss: 0.341360
# Epoch [30/1000], Train Loss: 0.321693, Val Loss: 0.337094
# Epoch [31/1000], Train Loss: 0.313084, Val Loss: 0.322407
# Epoch [32/1000], Train Loss: 0.300155, Val Loss: 0.301453
# Epoch [33/1000], Train Loss: 0.288790, Val Loss: 0.289189
# Epoch [34/1000], Train Loss: 0.279233, Val Loss: 0.280365
# Epoch [35/1000], Train Loss: 0.269307, Val Loss: 0.268825
# Epoch [36/1000], Train Loss: 0.260549, Val Loss: 0.258194
# Epoch [37/1000], Train Loss: 0.251967, Val Loss: 0.255851
# Epoch [38/1000], Train Loss: 0.244908, Val Loss: 0.252311
# Epoch [39/1000], Train Loss: 0.235839, Val Loss: 0.246659
# Epoch [40/1000], Train Loss: 0.229117, Val Loss: 0.245038
# Epoch [41/1000], Train Loss: 0.224261, Val Loss: 0.240330
# Epoch [42/1000], Train Loss: 0.224143, Val Loss: 0.229165
# Epoch [43/1000], Train Loss: 0.211307, Val Loss: 0.225822
# Epoch [44/1000], Train Loss: 0.208791, Val Loss: 0.218749
# Epoch [45/1000], Train Loss: 0.202891, Val Loss: 0.229132
# Epoch [46/1000], Train Loss: 0.205304, Val Loss: 0.217748
# Epoch [47/1000], Train Loss: 0.195296, Val Loss: 0.220396
# Epoch [48/1000], Train Loss: 0.193044, Val Loss: 0.209036
# Epoch [49/1000], Train Loss: 0.192402, Val Loss: 0.212027
# Epoch [50/1000], Train Loss: 0.190763, Val Loss: 0.207543
# Epoch [51/1000], Train Loss: 0.185573, Val Loss: 0.203972
# Epoch [52/1000], Train Loss: 0.181127, Val Loss: 0.199130
# Epoch [53/1000], Train Loss: 0.178459, Val Loss: 0.200994
# Epoch [54/1000], Train Loss: 0.175744, Val Loss: 0.194457
# Epoch [55/1000], Train Loss: 0.173206, Val Loss: 0.193110
# Epoch [56/1000], Train Loss: 0.171068, Val Loss: 0.191428
# Epoch [57/1000], Train Loss: 0.169168, Val Loss: 0.189913
# Epoch [58/1000], Train Loss: 0.167008, Val Loss: 0.189075
# Epoch [59/1000], Train Loss: 0.165293, Val Loss: 0.186881
# Epoch [60/1000], Train Loss: 0.163455, Val Loss: 0.184406
# Epoch [61/1000], Train Loss: 0.161818, Val Loss: 0.185882
# Epoch [62/1000], Train Loss: 0.160921, Val Loss: 0.180980
# Epoch [63/1000], Train Loss: 0.158187, Val Loss: 0.179385
# Epoch [64/1000], Train Loss: 0.157282, Val Loss: 0.179101
# Epoch [65/1000], Train Loss: 0.155483, Val Loss: 0.176830
# Epoch [66/1000], Train Loss: 0.153677, Val Loss: 0.175319
# Epoch [67/1000], Train Loss: 0.152196, Val Loss: 0.174188
# Epoch [68/1000], Train Loss: 0.151621, Val Loss: 0.173601
# Epoch [69/1000], Train Loss: 0.149285, Val Loss: 0.171269
# Epoch [70/1000], Train Loss: 0.147393, Val Loss: 0.171949
# Epoch [71/1000], Train Loss: 0.146169, Val Loss: 0.170539
# Epoch [72/1000], Train Loss: 0.145015, Val Loss: 0.169886
# Epoch [73/1000], Train Loss: 0.145008, Val Loss: 0.169142
# Epoch [74/1000], Train Loss: 0.141898, Val Loss: 0.168011
# Epoch [75/1000], Train Loss: 0.140686, Val Loss: 0.166666
# Epoch [76/1000], Train Loss: 0.140582, Val Loss: 0.166677
# Epoch [77/1000], Train Loss: 0.139466, Val Loss: 0.164657
# Epoch [78/1000], Train Loss: 0.137786, Val Loss: 0.163642
# Epoch [79/1000], Train Loss: 0.135684, Val Loss: 0.161237
# Epoch [80/1000], Train Loss: 0.136904, Val Loss: 0.160959
# Epoch [81/1000], Train Loss: 0.134147, Val Loss: 0.159035
# Epoch [82/1000], Train Loss: 0.133508, Val Loss: 0.157232
# Epoch [83/1000], Train Loss: 0.131815, Val Loss: 0.155972
# Epoch [84/1000], Train Loss: 0.130323, Val Loss: 0.154625
# Epoch [85/1000], Train Loss: 0.129201, Val Loss: 0.153363
# Epoch [86/1000], Train Loss: 0.127107, Val Loss: 0.161915
# Epoch [87/1000], Train Loss: 0.128060, Val Loss: 0.161529
# Epoch [88/1000], Train Loss: 0.124730, Val Loss: 0.160887
# Epoch [89/1000], Train Loss: 0.124707, Val Loss: 0.158306
# Epoch [90/1000], Train Loss: 0.123075, Val Loss: 0.157717
# Epoch [91/1000], Train Loss: 0.121813, Val Loss: 0.156191
# Epoch [92/1000], Train Loss: 0.120553, Val Loss: 0.154280
# Epoch [93/1000], Train Loss: 0.119466, Val Loss: 0.162251
# Epoch [94/1000], Train Loss: 0.118348, Val Loss: 0.160148
# Epoch [95/1000], Train Loss: 0.117481, Val Loss: 0.158895
# Epoch [96/1000], Train Loss: 0.116287, Val Loss: 0.157623
# Epoch [97/1000], Train Loss: 0.115272, Val Loss: 0.155844
# Epoch [98/1000], Train Loss: 0.114139, Val Loss: 0.155029
# Epoch [99/1000], Train Loss: 0.114242, Val Loss: 0.144601
# Epoch [100/1000], Train Loss: 0.112893, Val Loss: 0.135795
# Epoch [101/1000], Train Loss: 0.111109, Val Loss: 0.143622
# Epoch [102/1000], Train Loss: 0.109692, Val Loss: 0.150952
# Epoch [103/1000], Train Loss: 0.109768, Val Loss: 0.141803
# Epoch [104/1000], Train Loss: 0.107857, Val Loss: 0.150122
# Epoch [105/1000], Train Loss: 0.108859, Val Loss: 0.140942
# Epoch [106/1000], Train Loss: 0.106117, Val Loss: 0.148788
# Epoch [107/1000], Train Loss: 0.106375, Val Loss: 0.139170
# Epoch [108/1000], Train Loss: 0.104831, Val Loss: 0.139649
# Epoch [109/1000], Train Loss: 0.105119, Val Loss: 0.144601
# Epoch [110/1000], Train Loss: 0.103700, Val Loss: 0.136288
# Epoch [111/1000], Train Loss: 0.103300, Val Loss: 0.135570
# Epoch [112/1000], Train Loss: 0.101535, Val Loss: 0.134315
# Epoch [113/1000], Train Loss: 0.101384, Val Loss: 0.133169
# Epoch [114/1000], Train Loss: 0.099444, Val Loss: 0.133475
# Epoch [115/1000], Train Loss: 0.100255, Val Loss: 0.130691
# Epoch [116/1000], Train Loss: 0.097682, Val Loss: 0.131928
# Epoch [117/1000], Train Loss: 0.098588, Val Loss: 0.128835
# Epoch [118/1000], Train Loss: 0.096424, Val Loss: 0.129987
# Epoch [119/1000], Train Loss: 0.096795, Val Loss: 0.127326
# Epoch [120/1000], Train Loss: 0.096026, Val Loss: 0.127441
# Epoch [121/1000], Train Loss: 0.094006, Val Loss: 0.127390
# Epoch [122/1000], Train Loss: 0.094726, Val Loss: 0.125275
# Epoch [123/1000], Train Loss: 0.092685, Val Loss: 0.125877
# Epoch [124/1000], Train Loss: 0.093347, Val Loss: 0.124100
# Epoch [125/1000], Train Loss: 0.092255, Val Loss: 0.124003
# Epoch [126/1000], Train Loss: 0.091628, Val Loss: 0.121921
# Epoch [127/1000], Train Loss: 0.089829, Val Loss: 0.121901
# Epoch [128/1000], Train Loss: 0.089946, Val Loss: 0.121149
# Epoch [129/1000], Train Loss: 0.089506, Val Loss: 0.120971
# Epoch [130/1000], Train Loss: 0.088917, Val Loss: 0.119593
# Epoch [131/1000], Train Loss: 0.088156, Val Loss: 0.119411
# Epoch [132/1000], Train Loss: 0.087666, Val Loss: 0.117585
# Epoch [133/1000], Train Loss: 0.086832, Val Loss: 0.118172
# Epoch [134/1000], Train Loss: 0.086426, Val Loss: 0.116266
# Epoch [135/1000], Train Loss: 0.085578, Val Loss: 0.116664
# Epoch [136/1000], Train Loss: 0.085211, Val Loss: 0.115437
# Epoch [137/1000], Train Loss: 0.084379, Val Loss: 0.115122
# Epoch [138/1000], Train Loss: 0.083914, Val Loss: 0.115175
# Epoch [139/1000], Train Loss: 0.083522, Val Loss: 0.113854
# Epoch [140/1000], Train Loss: 0.083072, Val Loss: 0.113275
# Epoch [141/1000], Train Loss: 0.082132, Val Loss: 0.112733
# Epoch [142/1000], Train Loss: 0.082007, Val Loss: 0.111643
# Epoch [143/1000], Train Loss: 0.081201, Val Loss: 0.111367
# Epoch [144/1000], Train Loss: 0.080895, Val Loss: 0.110677
# Epoch [145/1000], Train Loss: 0.080217, Val Loss: 0.109680
# Epoch [146/1000], Train Loss: 0.079569, Val Loss: 0.109974
# Epoch [147/1000], Train Loss: 0.079303, Val Loss: 0.107953
# Epoch [148/1000], Train Loss: 0.079012, Val Loss: 0.108171
# Epoch [149/1000], Train Loss: 0.078477, Val Loss: 0.108112
# Epoch [150/1000], Train Loss: 0.077789, Val Loss: 0.107747
# Epoch [151/1000], Train Loss: 0.077491, Val Loss: 0.106869
# Epoch [152/1000], Train Loss: 0.077423, Val Loss: 0.105307
# Epoch [153/1000], Train Loss: 0.076602, Val Loss: 0.106030
# Epoch [154/1000], Train Loss: 0.076343, Val Loss: 0.103955
# Epoch [155/1000], Train Loss: 0.075822, Val Loss: 0.104802
# Epoch [156/1000], Train Loss: 0.075717, Val Loss: 0.103453
# Epoch [157/1000], Train Loss: 0.075183, Val Loss: 0.103546
# Epoch [158/1000], Train Loss: 0.074866, Val Loss: 0.102643
# Epoch [159/1000], Train Loss: 0.074481, Val Loss: 0.102947
# Epoch [160/1000], Train Loss: 0.074103, Val Loss: 0.101857
# Epoch [161/1000], Train Loss: 0.073748, Val Loss: 0.101681
# Epoch [162/1000], Train Loss: 0.073602, Val Loss: 0.100759
# Epoch [163/1000], Train Loss: 0.073005, Val Loss: 0.101365
# Epoch [164/1000], Train Loss: 0.072721, Val Loss: 0.101151
# Epoch [165/1000], Train Loss: 0.072724, Val Loss: 0.099353
# Epoch [166/1000], Train Loss: 0.072160, Val Loss: 0.099891
# Epoch [167/1000], Train Loss: 0.071850, Val Loss: 0.099731
# Epoch [168/1000], Train Loss: 0.071659, Val Loss: 0.099505
# Epoch [169/1000], Train Loss: 0.071254, Val Loss: 0.098900
# Epoch [170/1000], Train Loss: 0.070998, Val Loss: 0.098576
# Epoch [171/1000], Train Loss: 0.071036, Val Loss: 0.097071
# Epoch [172/1000], Train Loss: 0.070553, Val Loss: 0.098006
# Epoch [173/1000], Train Loss: 0.070378, Val Loss: 0.097970
# Epoch [174/1000], Train Loss: 0.070151, Val Loss: 0.097372
# Epoch [175/1000], Train Loss: 0.070097, Val Loss: 0.096488
# Epoch [176/1000], Train Loss: 0.069658, Val Loss: 0.096884
# Epoch [177/1000], Train Loss: 0.069711, Val Loss: 0.095056
# Epoch [178/1000], Train Loss: 0.069100, Val Loss: 0.096228
# Epoch [179/1000], Train Loss: 0.069275, Val Loss: 0.095421
# Epoch [180/1000], Train Loss: 0.068941, Val Loss: 0.095142
# Epoch [181/1000], Train Loss: 0.068700, Val Loss: 0.094051
# Epoch [182/1000], Train Loss: 0.068642, Val Loss: 0.093420
# Epoch [183/1000], Train Loss: 0.068261, Val Loss: 0.093206
# Epoch [184/1000], Train Loss: 0.068101, Val Loss: 0.094455
# Epoch [185/1000], Train Loss: 0.068010, Val Loss: 0.093574
# Epoch [186/1000], Train Loss: 0.067759, Val Loss: 0.092377
# Epoch [187/1000], Train Loss: 0.067550, Val Loss: 0.092840
# Epoch [188/1000], Train Loss: 0.067356, Val Loss: 0.092222
# Epoch [189/1000], Train Loss: 0.067215, Val Loss: 0.092878
# Epoch [190/1000], Train Loss: 0.067084, Val Loss: 0.091675
# Epoch [191/1000], Train Loss: 0.066828, Val Loss: 0.092348
# Epoch [192/1000], Train Loss: 0.066770, Val Loss: 0.092259
# Epoch [193/1000], Train Loss: 0.066376, Val Loss: 0.091779
# Epoch [194/1000], Train Loss: 0.066386, Val Loss: 0.090970
# Epoch [195/1000], Train Loss: 0.066227, Val Loss: 0.091067
# Epoch [196/1000], Train Loss: 0.066154, Val Loss: 0.091163
# Epoch [197/1000], Train Loss: 0.065810, Val Loss: 0.090154
# Epoch [198/1000], Train Loss: 0.065700, Val Loss: 0.089559
# Epoch [199/1000], Train Loss: 0.065486, Val Loss: 0.090122
# Epoch [200/1000], Train Loss: 0.065397, Val Loss: 0.090932
# Epoch [201/1000], Train Loss: 0.065070, Val Loss: 0.089680
# Epoch [202/1000], Train Loss: 0.065217, Val Loss: 0.090102
# Epoch [203/1000], Train Loss: 0.064778, Val Loss: 0.089590
# Epoch [204/1000], Train Loss: 0.065095, Val Loss: 0.089204
# Epoch [205/1000], Train Loss: 0.064547, Val Loss: 0.089689
# Epoch [206/1000], Train Loss: 0.064826, Val Loss: 0.089364
# Epoch [207/1000], Train Loss: 0.064360, Val Loss: 0.089079
# Epoch [208/1000], Train Loss: 0.064424, Val Loss: 0.089004
# Epoch [209/1000], Train Loss: 0.064373, Val Loss: 0.089143
# Epoch [210/1000], Train Loss: 0.064037, Val Loss: 0.088644
# Epoch [211/1000], Train Loss: 0.063860, Val Loss: 0.088730
# Epoch [212/1000], Train Loss: 0.063739, Val Loss: 0.089078
# Epoch [213/1000], Train Loss: 0.063631, Val Loss: 0.088653
# Epoch [214/1000], Train Loss: 0.063593, Val Loss: 0.088695
# Epoch [215/1000], Train Loss: 0.063388, Val Loss: 0.087963
# Epoch [216/1000], Train Loss: 0.063258, Val Loss: 0.088242
# Epoch [217/1000], Train Loss: 0.063019, Val Loss: 0.088770
# Epoch [218/1000], Train Loss: 0.063122, Val Loss: 0.088367
# Epoch [219/1000], Train Loss: 0.063149, Val Loss: 0.087798
# Epoch [220/1000], Train Loss: 0.062708, Val Loss: 0.088296
# Epoch [221/1000], Train Loss: 0.062618, Val Loss: 0.087937
# Epoch [222/1000], Train Loss: 0.062512, Val Loss: 0.087622
# Epoch [223/1000], Train Loss: 0.062273, Val Loss: 0.087670
# Epoch [224/1000], Train Loss: 0.062336, Val Loss: 0.087757
# Epoch [225/1000], Train Loss: 0.062303, Val Loss: 0.087350
# Epoch [226/1000], Train Loss: 0.061898, Val Loss: 0.087642
# Epoch [227/1000], Train Loss: 0.061920, Val Loss: 0.087723
# Epoch [228/1000], Train Loss: 0.061814, Val Loss: 0.087162
# Epoch [229/1000], Train Loss: 0.061878, Val Loss: 0.086791
# Epoch [230/1000], Train Loss: 0.061507, Val Loss: 0.086404
# Epoch [231/1000], Train Loss: 0.061407, Val Loss: 0.086461
# Epoch [232/1000], Train Loss: 0.061451, Val Loss: 0.086142
# Epoch [233/1000], Train Loss: 0.061124, Val Loss: 0.086839
# Epoch [234/1000], Train Loss: 0.061154, Val Loss: 0.086663
# Epoch [235/1000], Train Loss: 0.061157, Val Loss: 0.085873
# Epoch [236/1000], Train Loss: 0.060807, Val Loss: 0.086632
# Epoch [237/1000], Train Loss: 0.060811, Val Loss: 0.086150
# Epoch [238/1000], Train Loss: 0.060748, Val Loss: 0.086180
# Epoch [239/1000], Train Loss: 0.060585, Val Loss: 0.085620
# Epoch [240/1000], Train Loss: 0.060445, Val Loss: 0.085555
# Epoch [241/1000], Train Loss: 0.060443, Val Loss: 0.085825
# Epoch [242/1000], Train Loss: 0.060166, Val Loss: 0.085765
# Epoch [243/1000], Train Loss: 0.060206, Val Loss: 0.084816
# Epoch [244/1000], Train Loss: 0.060066, Val Loss: 0.086141
# Epoch [245/1000], Train Loss: 0.059982, Val Loss: 0.085604
# Epoch [246/1000], Train Loss: 0.059829, Val Loss: 0.085700
# Epoch [247/1000], Train Loss: 0.059922, Val Loss: 0.084724
# Epoch [248/1000], Train Loss: 0.059537, Val Loss: 0.085644
# Epoch [249/1000], Train Loss: 0.059695, Val Loss: 0.084411
# Epoch [250/1000], Train Loss: 0.059485, Val Loss: 0.085228
# Epoch [251/1000], Train Loss: 0.059351, Val Loss: 0.084511
# Epoch [252/1000], Train Loss: 0.059412, Val Loss: 0.083369
# Epoch [253/1000], Train Loss: 0.059096, Val Loss: 0.085296
# Epoch [254/1000], Train Loss: 0.059119, Val Loss: 0.084849
# Epoch [255/1000], Train Loss: 0.059098, Val Loss: 0.083854
# Epoch [256/1000], Train Loss: 0.059044, Val Loss: 0.083926
# Epoch [257/1000], Train Loss: 0.058752, Val Loss: 0.084161
# Epoch [258/1000], Train Loss: 0.059089, Val Loss: 0.083036
# Epoch [259/1000], Train Loss: 0.058582, Val Loss: 0.084183
# Epoch [260/1000], Train Loss: 0.058632, Val Loss: 0.083648
# Epoch [261/1000], Train Loss: 0.058431, Val Loss: 0.083919
# Epoch [262/1000], Train Loss: 0.058429, Val Loss: 0.083784
# Epoch [263/1000], Train Loss: 0.058469, Val Loss: 0.082884
# Epoch [264/1000], Train Loss: 0.058037, Val Loss: 0.084457
# Epoch [265/1000], Train Loss: 0.058273, Val Loss: 0.083599
# Epoch [266/1000], Train Loss: 0.058013, Val Loss: 0.084041
# Epoch [267/1000], Train Loss: 0.058008, Val Loss: 0.083141
# Epoch [268/1000], Train Loss: 0.057956, Val Loss: 0.083140
# Epoch [269/1000], Train Loss: 0.057719, Val Loss: 0.083656
# Epoch [270/1000], Train Loss: 0.057843, Val Loss: 0.083080
# Epoch [271/1000], Train Loss: 0.057681, Val Loss: 0.083094
# Epoch [272/1000], Train Loss: 0.057575, Val Loss: 0.083054
# Epoch [273/1000], Train Loss: 0.057567, Val Loss: 0.082430
# Epoch [274/1000], Train Loss: 0.057374, Val Loss: 0.082865
# Epoch [275/1000], Train Loss: 0.057422, Val Loss: 0.082271
# Epoch [276/1000], Train Loss: 0.057292, Val Loss: 0.082535
# Epoch [277/1000], Train Loss: 0.057037, Val Loss: 0.083000
# Epoch [278/1000], Train Loss: 0.057050, Val Loss: 0.083260
# Epoch [279/1000], Train Loss: 0.057169, Val Loss: 0.081809
# Epoch [280/1000], Train Loss: 0.056761, Val Loss: 0.083376
# Epoch [281/1000], Train Loss: 0.057059, Val Loss: 0.081164
# Epoch [282/1000], Train Loss: 0.056708, Val Loss: 0.082257
# Epoch [283/1000], Train Loss: 0.056698, Val Loss: 0.082642
# Epoch [284/1000], Train Loss: 0.056720, Val Loss: 0.081520
# Epoch [285/1000], Train Loss: 0.056654, Val Loss: 0.081654
# Epoch [286/1000], Train Loss: 0.056475, Val Loss: 0.081708
# Epoch [287/1000], Train Loss: 0.056354, Val Loss: 0.082304
# Epoch [288/1000], Train Loss: 0.056473, Val Loss: 0.081132
# Epoch [289/1000], Train Loss: 0.056268, Val Loss: 0.081859
# Epoch [290/1000], Train Loss: 0.056190, Val Loss: 0.082098
# Epoch [291/1000], Train Loss: 0.056266, Val Loss: 0.080587
# Epoch [292/1000], Train Loss: 0.055869, Val Loss: 0.082220
# Epoch [293/1000], Train Loss: 0.055995, Val Loss: 0.080855
# Epoch [294/1000], Train Loss: 0.055688, Val Loss: 0.081919
# Epoch [295/1000], Train Loss: 0.055750, Val Loss: 0.080870
# Epoch [296/1000], Train Loss: 0.055752, Val Loss: 0.080484
# Epoch [297/1000], Train Loss: 0.055609, Val Loss: 0.080432
# Epoch [298/1000], Train Loss: 0.055611, Val Loss: 0.079973
# Epoch [299/1000], Train Loss: 0.055425, Val Loss: 0.080662
# Epoch [300/1000], Train Loss: 0.055308, Val Loss: 0.081705
# Epoch [301/1000], Train Loss: 0.055485, Val Loss: 0.079481
# Epoch [302/1000], Train Loss: 0.055300, Val Loss: 0.079549
# Epoch [303/1000], Train Loss: 0.055182, Val Loss: 0.080134
# Epoch [304/1000], Train Loss: 0.055085, Val Loss: 0.080511
# Epoch [305/1000], Train Loss: 0.055111, Val Loss: 0.079690
# Epoch [306/1000], Train Loss: 0.054987, Val Loss: 0.079657
# Epoch [307/1000], Train Loss: 0.055027, Val Loss: 0.078893
# Epoch [308/1000], Train Loss: 0.054922, Val Loss: 0.079214
# Epoch [309/1000], Train Loss: 0.054875, Val Loss: 0.079222
# Epoch [310/1000], Train Loss: 0.054700, Val Loss: 0.078646
# Epoch [311/1000], Train Loss: 0.054788, Val Loss: 0.078937
# Epoch [312/1000], Train Loss: 0.054654, Val Loss: 0.077395
# Epoch [313/1000], Train Loss: 0.054353, Val Loss: 0.079538
# Epoch [314/1000], Train Loss: 0.054441, Val Loss: 0.079887
# Epoch [315/1000], Train Loss: 0.054387, Val Loss: 0.079517
# Epoch [316/1000], Train Loss: 0.054497, Val Loss: 0.077446
# Epoch [317/1000], Train Loss: 0.054108, Val Loss: 0.078867
# Epoch [318/1000], Train Loss: 0.054307, Val Loss: 0.078218
# Epoch [319/1000], Train Loss: 0.054386, Val Loss: 0.076671
# Epoch [320/1000], Train Loss: 0.053929, Val Loss: 0.078782
# Epoch [321/1000], Train Loss: 0.053814, Val Loss: 0.080103
# Epoch [322/1000], Train Loss: 0.053616, Val Loss: 0.078659
# Epoch [323/1000], Train Loss: 0.053924, Val Loss: 0.078279
# Epoch [324/1000], Train Loss: 0.053973, Val Loss: 0.075983
# Epoch [325/1000], Train Loss: 0.053683, Val Loss: 0.077667
# Epoch [326/1000], Train Loss: 0.053639, Val Loss: 0.078711
# Epoch [327/1000], Train Loss: 0.053403, Val Loss: 0.078720
# Epoch [328/1000], Train Loss: 0.053587, Val Loss: 0.077785
# Epoch [329/1000], Train Loss: 0.053161, Val Loss: 0.078549
# Epoch [330/1000], Train Loss: 0.053401, Val Loss: 0.078367
# Epoch [331/1000], Train Loss: 0.053595, Val Loss: 0.076526
# Epoch [332/1000], Train Loss: 0.053127, Val Loss: 0.078388
# Epoch [333/1000], Train Loss: 0.053319, Val Loss: 0.076973
# Epoch [334/1000], Train Loss: 0.053204, Val Loss: 0.078302
# Epoch [335/1000], Train Loss: 0.053124, Val Loss: 0.076779
# Epoch [336/1000], Train Loss: 0.053215, Val Loss: 0.075228
# Epoch [337/1000], Train Loss: 0.052930, Val Loss: 0.078003
# Epoch [338/1000], Train Loss: 0.052609, Val Loss: 0.076592
# Epoch [339/1000], Train Loss: 0.052804, Val Loss: 0.077134
# Epoch [340/1000], Train Loss: 0.052861, Val Loss: 0.077841
# Epoch [341/1000], Train Loss: 0.052639, Val Loss: 0.077245
# Epoch [342/1000], Train Loss: 0.052692, Val Loss: 0.077582
# Epoch [343/1000], Train Loss: 0.052651, Val Loss: 0.074905
# Epoch [344/1000], Train Loss: 0.052513, Val Loss: 0.076695
# Epoch [345/1000], Train Loss: 0.052541, Val Loss: 0.077573
# Epoch [346/1000], Train Loss: 0.052588, Val Loss: 0.074702
# Epoch [347/1000], Train Loss: 0.052402, Val Loss: 0.076622
# Epoch [348/1000], Train Loss: 0.052361, Val Loss: 0.077277
# Epoch [349/1000], Train Loss: 0.052378, Val Loss: 0.074988
# Epoch [350/1000], Train Loss: 0.051979, Val Loss: 0.074878
# Epoch [351/1000], Train Loss: 0.052269, Val Loss: 0.075294
# Epoch [352/1000], Train Loss: 0.052045, Val Loss: 0.076942
# Epoch [353/1000], Train Loss: 0.051959, Val Loss: 0.076862
# Epoch [354/1000], Train Loss: 0.051829, Val Loss: 0.074845
# Epoch [355/1000], Train Loss: 0.051856, Val Loss: 0.077265
# Epoch [356/1000], Train Loss: 0.051922, Val Loss: 0.074233
# Epoch [357/1000], Train Loss: 0.051660, Val Loss: 0.074603
# Epoch [358/1000], Train Loss: 0.051620, Val Loss: 0.077270
# Epoch [359/1000], Train Loss: 0.051726, Val Loss: 0.075125
# Epoch [360/1000], Train Loss: 0.051560, Val Loss: 0.074574
# Epoch [361/1000], Train Loss: 0.051546, Val Loss: 0.075976
# Epoch [362/1000], Train Loss: 0.051790, Val Loss: 0.074701
# Epoch [363/1000], Train Loss: 0.051319, Val Loss: 0.076405
# Epoch [364/1000], Train Loss: 0.051514, Val Loss: 0.073652
# Epoch [365/1000], Train Loss: 0.051277, Val Loss: 0.076806
# Epoch [366/1000], Train Loss: 0.051467, Val Loss: 0.074489
# Epoch [367/1000], Train Loss: 0.051461, Val Loss: 0.074099
# Epoch [368/1000], Train Loss: 0.050761, Val Loss: 0.077036
# Epoch [369/1000], Train Loss: 0.051424, Val Loss: 0.074189
# Epoch [370/1000], Train Loss: 0.050876, Val Loss: 0.075085
# Epoch [371/1000], Train Loss: 0.051140, Val Loss: 0.075424
# Epoch [372/1000], Train Loss: 0.050813, Val Loss: 0.075386
# Epoch [373/1000], Train Loss: 0.051084, Val Loss: 0.075571
# Epoch [374/1000], Train Loss: 0.050707, Val Loss: 0.074103
# Epoch [375/1000], Train Loss: 0.051157, Val Loss: 0.073631
# Epoch [376/1000], Train Loss: 0.050670, Val Loss: 0.076460
# Epoch [377/1000], Train Loss: 0.050780, Val Loss: 0.073904
# Epoch [378/1000], Train Loss: 0.050689, Val Loss: 0.076166
# Epoch [379/1000], Train Loss: 0.050955, Val Loss: 0.073435
# Epoch [380/1000], Train Loss: 0.050306, Val Loss: 0.076050
# Epoch [381/1000], Train Loss: 0.050662, Val Loss: 0.073914
# Epoch [382/1000], Train Loss: 0.050265, Val Loss: 0.074888
# Epoch [383/1000], Train Loss: 0.050554, Val Loss: 0.075597
# Epoch [384/1000], Train Loss: 0.050604, Val Loss: 0.074608
# Epoch [385/1000], Train Loss: 0.050360, Val Loss: 0.072471
# Epoch [386/1000], Train Loss: 0.050207, Val Loss: 0.075939
# Epoch [387/1000], Train Loss: 0.050583, Val Loss: 0.072940
# Epoch [388/1000], Train Loss: 0.050021, Val Loss: 0.073395
# Epoch [389/1000], Train Loss: 0.050239, Val Loss: 0.075291
# Epoch [390/1000], Train Loss: 0.050322, Val Loss: 0.073774
# Epoch [391/1000], Train Loss: 0.049847, Val Loss: 0.073500
# Epoch [392/1000], Train Loss: 0.050012, Val Loss: 0.075616
# Epoch [393/1000], Train Loss: 0.050279, Val Loss: 0.073476
# Epoch [394/1000], Train Loss: 0.049859, Val Loss: 0.072439
# Epoch [395/1000], Train Loss: 0.049893, Val Loss: 0.075223
# Epoch [396/1000], Train Loss: 0.050037, Val Loss: 0.073665
# Epoch [397/1000], Train Loss: 0.049788, Val Loss: 0.071858
# Epoch [398/1000], Train Loss: 0.049662, Val Loss: 0.075822
# Epoch [399/1000], Train Loss: 0.049703, Val Loss: 0.072513
# Epoch [400/1000], Train Loss: 0.049823, Val Loss: 0.072906
# Epoch [401/1000], Train Loss: 0.049847, Val Loss: 0.073342
# Epoch [402/1000], Train Loss: 0.049631, Val Loss: 0.074722
# Epoch [403/1000], Train Loss: 0.049448, Val Loss: 0.073661
# Epoch [404/1000], Train Loss: 0.049722, Val Loss: 0.072399
# Epoch [405/1000], Train Loss: 0.049230, Val Loss: 0.072629
# Epoch [406/1000], Train Loss: 0.049731, Val Loss: 0.072995
# Epoch [407/1000], Train Loss: 0.049497, Val Loss: 0.072715
# Epoch [408/1000], Train Loss: 0.049598, Val Loss: 0.071554
# Epoch [409/1000], Train Loss: 0.048879, Val Loss: 0.075224
# Epoch [410/1000], Train Loss: 0.049492, Val Loss: 0.071405
# Epoch [411/1000], Train Loss: 0.049212, Val Loss: 0.075110
# Epoch [412/1000], Train Loss: 0.049403, Val Loss: 0.071832
# Epoch [413/1000], Train Loss: 0.048901, Val Loss: 0.072844
# Epoch [414/1000], Train Loss: 0.049149, Val Loss: 0.073422
# Epoch [415/1000], Train Loss: 0.048936, Val Loss: 0.072492
# Epoch [416/1000], Train Loss: 0.049043, Val Loss: 0.072417
# Epoch [417/1000], Train Loss: 0.049266, Val Loss: 0.072465
# Epoch [418/1000], Train Loss: 0.048858, Val Loss: 0.072996
# Epoch [419/1000], Train Loss: 0.049023, Val Loss: 0.071673
# Epoch [420/1000], Train Loss: 0.048660, Val Loss: 0.072671
# Epoch [421/1000], Train Loss: 0.048988, Val Loss: 0.071344
# Epoch [422/1000], Train Loss: 0.048452, Val Loss: 0.072835
# Epoch [423/1000], Train Loss: 0.048916, Val Loss: 0.071992
# Epoch [424/1000], Train Loss: 0.048748, Val Loss: 0.071757
# Epoch [425/1000], Train Loss: 0.048472, Val Loss: 0.071934
# Epoch [426/1000], Train Loss: 0.048700, Val Loss: 0.072330
# Epoch [427/1000], Train Loss: 0.048575, Val Loss: 0.073899
# Epoch [428/1000], Train Loss: 0.048567, Val Loss: 0.071993
# Epoch [429/1000], Train Loss: 0.048425, Val Loss: 0.072004
# Epoch [430/1000], Train Loss: 0.048570, Val Loss: 0.071729
# Epoch [431/1000], Train Loss: 0.048454, Val Loss: 0.071788
# Epoch [432/1000], Train Loss: 0.048457, Val Loss: 0.071644
# Epoch [433/1000], Train Loss: 0.048384, Val Loss: 0.071475
# Epoch [434/1000], Train Loss: 0.048041, Val Loss: 0.071874
# Epoch [435/1000], Train Loss: 0.048327, Val Loss: 0.071791
# Epoch [436/1000], Train Loss: 0.048406, Val Loss: 0.067281
# Epoch [437/1000], Train Loss: 0.047791, Val Loss: 0.074232
# Epoch [438/1000], Train Loss: 0.048047, Val Loss: 0.071407
# Epoch [439/1000], Train Loss: 0.048228, Val Loss: 0.071335
# Epoch [440/1000], Train Loss: 0.048095, Val Loss: 0.072018
# Epoch [441/1000], Train Loss: 0.047778, Val Loss: 0.071821
# Epoch [442/1000], Train Loss: 0.048073, Val Loss: 0.071871
# Epoch [443/1000], Train Loss: 0.048045, Val Loss: 0.067943
# Epoch [444/1000], Train Loss: 0.047538, Val Loss: 0.074017
# Epoch [445/1000], Train Loss: 0.047833, Val Loss: 0.072347
# Epoch [446/1000], Train Loss: 0.048068, Val Loss: 0.070675
# Epoch [447/1000], Train Loss: 0.047696, Val Loss: 0.068473
# Epoch [448/1000], Train Loss: 0.047672, Val Loss: 0.072543
# Epoch [449/1000], Train Loss: 0.047512, Val Loss: 0.067593
# Epoch [450/1000], Train Loss: 0.047490, Val Loss: 0.067539
# Epoch [451/1000], Train Loss: 0.047664, Val Loss: 0.068048
# Epoch [452/1000], Train Loss: 0.047451, Val Loss: 0.073366
# Epoch [453/1000], Train Loss: 0.047583, Val Loss: 0.071004
# Epoch [454/1000], Train Loss: 0.047653, Val Loss: 0.067915
# Epoch [455/1000], Train Loss: 0.047342, Val Loss: 0.067053
# Epoch [456/1000], Train Loss: 0.047080, Val Loss: 0.073075
# Epoch [457/1000], Train Loss: 0.047694, Val Loss: 0.070979
# Epoch [458/1000], Train Loss: 0.047499, Val Loss: 0.067786
# Epoch [459/1000], Train Loss: 0.047045, Val Loss: 0.066300
# Epoch [460/1000], Train Loss: 0.047060, Val Loss: 0.072720
# Epoch [461/1000], Train Loss: 0.047598, Val Loss: 0.066644
# Epoch [462/1000], Train Loss: 0.046946, Val Loss: 0.072641
# Epoch [463/1000], Train Loss: 0.047191, Val Loss: 0.067782
# Epoch [464/1000], Train Loss: 0.047188, Val Loss: 0.066298
# Epoch [465/1000], Train Loss: 0.046819, Val Loss: 0.073299
# Epoch [466/1000], Train Loss: 0.047221, Val Loss: 0.069687
# Epoch [467/1000], Train Loss: 0.047053, Val Loss: 0.067973
# Epoch [468/1000], Train Loss: 0.047002, Val Loss: 0.066851
# Epoch [469/1000], Train Loss: 0.046793, Val Loss: 0.067973
# Epoch [470/1000], Train Loss: 0.046946, Val Loss: 0.066768
# Epoch [471/1000], Train Loss: 0.046765, Val Loss: 0.073064
# Epoch [472/1000], Train Loss: 0.047095, Val Loss: 0.066906
# Epoch [473/1000], Train Loss: 0.046282, Val Loss: 0.071687
# Epoch [474/1000], Train Loss: 0.047055, Val Loss: 0.068014
# Epoch [475/1000], Train Loss: 0.046774, Val Loss: 0.066674
# Epoch [476/1000], Train Loss: 0.046472, Val Loss: 0.067248
# Epoch [477/1000], Train Loss: 0.046617, Val Loss: 0.072159
# Epoch [478/1000], Train Loss: 0.046813, Val Loss: 0.066798
# Epoch [479/1000], Train Loss: 0.046514, Val Loss: 0.071346
# Epoch [480/1000], Train Loss: 0.046460, Val Loss: 0.066165
# Epoch [481/1000], Train Loss: 0.046529, Val Loss: 0.071047
# Epoch [482/1000], Train Loss: 0.046639, Val Loss: 0.066297
# Epoch [483/1000], Train Loss: 0.046052, Val Loss: 0.071263
# Epoch [484/1000], Train Loss: 0.046672, Val Loss: 0.066457
# Epoch [485/1000], Train Loss: 0.046261, Val Loss: 0.071232
# Epoch [486/1000], Train Loss: 0.046312, Val Loss: 0.066733
# Epoch [487/1000], Train Loss: 0.046339, Val Loss: 0.066178
# Epoch [488/1000], Train Loss: 0.046101, Val Loss: 0.067608
# Epoch [489/1000], Train Loss: 0.046182, Val Loss: 0.067237
# Epoch [490/1000], Train Loss: 0.046280, Val Loss: 0.066257
# Epoch [491/1000], Train Loss: 0.046018, Val Loss: 0.067588
# Epoch [492/1000], Train Loss: 0.046104, Val Loss: 0.065340
# Epoch [493/1000], Train Loss: 0.045948, Val Loss: 0.067307
# Epoch [494/1000], Train Loss: 0.046043, Val Loss: 0.071558
# Epoch [495/1000], Train Loss: 0.046086, Val Loss: 0.065760
# Epoch [496/1000], Train Loss: 0.045984, Val Loss: 0.066099
# Epoch [497/1000], Train Loss: 0.045905, Val Loss: 0.066675
# Epoch [498/1000], Train Loss: 0.045812, Val Loss: 0.065922
# Epoch [499/1000], Train Loss: 0.045843, Val Loss: 0.067311
# Epoch [500/1000], Train Loss: 0.045962, Val Loss: 0.065506
# Epoch [501/1000], Train Loss: 0.045532, Val Loss: 0.070904
# Epoch [502/1000], Train Loss: 0.046087, Val Loss: 0.065885
# Epoch [503/1000], Train Loss: 0.045672, Val Loss: 0.066414
# Epoch [504/1000], Train Loss: 0.045630, Val Loss: 0.065871
# Epoch [505/1000], Train Loss: 0.045650, Val Loss: 0.067148
# Epoch [506/1000], Train Loss: 0.045720, Val Loss: 0.070186
# Epoch [507/1000], Train Loss: 0.045632, Val Loss: 0.066162
# Epoch [508/1000], Train Loss: 0.045693, Val Loss: 0.064910
# Epoch [509/1000], Train Loss: 0.045354, Val Loss: 0.071408
# Epoch [510/1000], Train Loss: 0.045675, Val Loss: 0.065421
# Epoch [511/1000], Train Loss: 0.045429, Val Loss: 0.066685
# Epoch [512/1000], Train Loss: 0.045537, Val Loss: 0.065050
# Epoch [513/1000], Train Loss: 0.045229, Val Loss: 0.066201
# Epoch [514/1000], Train Loss: 0.045485, Val Loss: 0.066099
# Epoch [515/1000], Train Loss: 0.045314, Val Loss: 0.066102
# Epoch [516/1000], Train Loss: 0.045452, Val Loss: 0.070458
# Epoch [517/1000], Train Loss: 0.045213, Val Loss: 0.066371
# Epoch [518/1000], Train Loss: 0.045331, Val Loss: 0.066266
# Epoch [519/1000], Train Loss: 0.045251, Val Loss: 0.065972
# Epoch [520/1000], Train Loss: 0.045053, Val Loss: 0.066266
# Epoch [521/1000], Train Loss: 0.045174, Val Loss: 0.066738
# Epoch [522/1000], Train Loss: 0.045015, Val Loss: 0.066099
# Epoch [523/1000], Train Loss: 0.045074, Val Loss: 0.066698
# Epoch [524/1000], Train Loss: 0.045114, Val Loss: 0.067355
# Epoch [525/1000], Train Loss: 0.044990, Val Loss: 0.065575
# Epoch [526/1000], Train Loss: 0.045180, Val Loss: 0.065257
# Epoch [527/1000], Train Loss: 0.044861, Val Loss: 0.067604
# Epoch [528/1000], Train Loss: 0.045074, Val Loss: 0.066622
# Epoch [529/1000], Train Loss: 0.044622, Val Loss: 0.065603
# Epoch [530/1000], Train Loss: 0.045005, Val Loss: 0.066656
# Epoch [531/1000], Train Loss: 0.044989, Val Loss: 0.066783
# Epoch [532/1000], Train Loss: 0.044752, Val Loss: 0.064243
# Epoch [533/1000], Train Loss: 0.044707, Val Loss: 0.065477
# Epoch [534/1000], Train Loss: 0.044993, Val Loss: 0.064906
# Epoch [535/1000], Train Loss: 0.044400, Val Loss: 0.066397
# Epoch [536/1000], Train Loss: 0.044862, Val Loss: 0.064690
# Epoch [537/1000], Train Loss: 0.044701, Val Loss: 0.066168
# Epoch [538/1000], Train Loss: 0.044730, Val Loss: 0.066400
# Epoch [539/1000], Train Loss: 0.044533, Val Loss: 0.066782
# Epoch [540/1000], Train Loss: 0.044411, Val Loss: 0.064083
# Epoch [541/1000], Train Loss: 0.044599, Val Loss: 0.064355
# Epoch [542/1000], Train Loss: 0.044482, Val Loss: 0.065528
# Epoch [543/1000], Train Loss: 0.044367, Val Loss: 0.067089
# Epoch [544/1000], Train Loss: 0.044604, Val Loss: 0.065490
# Epoch [545/1000], Train Loss: 0.044072, Val Loss: 0.065802
# Epoch [546/1000], Train Loss: 0.044403, Val Loss: 0.065432
# Epoch [547/1000], Train Loss: 0.044387, Val Loss: 0.066109
# Epoch [548/1000], Train Loss: 0.044066, Val Loss: 0.065763
# Epoch [549/1000], Train Loss: 0.044196, Val Loss: 0.065548
# Epoch [550/1000], Train Loss: 0.044401, Val Loss: 0.065294
# Epoch [551/1000], Train Loss: 0.044103, Val Loss: 0.065446
# Epoch [552/1000], Train Loss: 0.044088, Val Loss: 0.065596
# Epoch [553/1000], Train Loss: 0.044190, Val Loss: 0.065290
# Epoch [554/1000], Train Loss: 0.044024, Val Loss: 0.065385
# Epoch [555/1000], Train Loss: 0.043676, Val Loss: 0.065498
# Epoch [556/1000], Train Loss: 0.044139, Val Loss: 0.065558
# Epoch [557/1000], Train Loss: 0.044031, Val Loss: 0.065348
# Epoch [558/1000], Train Loss: 0.043942, Val Loss: 0.064770
# Epoch [559/1000], Train Loss: 0.043910, Val Loss: 0.065185
# Epoch [560/1000], Train Loss: 0.043613, Val Loss: 0.064477
# Epoch [561/1000], Train Loss: 0.043728, Val Loss: 0.065751
# Epoch [562/1000], Train Loss: 0.043996, Val Loss: 0.064689
# Epoch [563/1000], Train Loss: 0.043442, Val Loss: 0.065060
# Epoch [564/1000], Train Loss: 0.043772, Val Loss: 0.064629
# Epoch [565/1000], Train Loss: 0.043762, Val Loss: 0.065385
# Epoch [566/1000], Train Loss: 0.043663, Val Loss: 0.064759
# Epoch [567/1000], Train Loss: 0.043486, Val Loss: 0.064928
# Epoch [568/1000], Train Loss: 0.043602, Val Loss: 0.064251
# Epoch [569/1000], Train Loss: 0.043596, Val Loss: 0.064968
# Epoch [570/1000], Train Loss: 0.043435, Val Loss: 0.063693
# Epoch [571/1000], Train Loss: 0.043431, Val Loss: 0.065019
# Epoch [572/1000], Train Loss: 0.043609, Val Loss: 0.064768
# Epoch [573/1000], Train Loss: 0.043186, Val Loss: 0.064425
# Epoch [574/1000], Train Loss: 0.043442, Val Loss: 0.064241
# Epoch [575/1000], Train Loss: 0.043272, Val Loss: 0.065458
# Epoch [576/1000], Train Loss: 0.043491, Val Loss: 0.064624
# Epoch [577/1000], Train Loss: 0.043233, Val Loss: 0.064734
# Epoch [578/1000], Train Loss: 0.043094, Val Loss: 0.064002
# Epoch [579/1000], Train Loss: 0.043113, Val Loss: 0.065063
# Epoch [580/1000], Train Loss: 0.043109, Val Loss: 0.064123
# Epoch [581/1000], Train Loss: 0.043081, Val Loss: 0.064284
# Epoch [582/1000], Train Loss: 0.043086, Val Loss: 0.064576
# Epoch [583/1000], Train Loss: 0.043071, Val Loss: 0.063811
# Epoch [584/1000], Train Loss: 0.042965, Val Loss: 0.064213
# Epoch [585/1000], Train Loss: 0.042809, Val Loss: 0.064080
# Epoch [586/1000], Train Loss: 0.042701, Val Loss: 0.064622
# Epoch [587/1000], Train Loss: 0.042812, Val Loss: 0.063976
# Epoch [588/1000], Train Loss: 0.042724, Val Loss: 0.064109
# Epoch [589/1000], Train Loss: 0.042872, Val Loss: 0.064152
# Epoch [590/1000], Train Loss: 0.042857, Val Loss: 0.063979
# Epoch [591/1000], Train Loss: 0.042681, Val Loss: 0.064741
# Epoch [592/1000], Train Loss: 0.042706, Val Loss: 0.064080
# Epoch [593/1000], Train Loss: 0.042556, Val Loss: 0.064497
# Epoch [594/1000], Train Loss: 0.042566, Val Loss: 0.063895
# Epoch [595/1000], Train Loss: 0.042479, Val Loss: 0.064380
# Epoch [596/1000], Train Loss: 0.042537, Val Loss: 0.063933
# Epoch [597/1000], Train Loss: 0.042383, Val Loss: 0.063812
# Epoch [598/1000], Train Loss: 0.042388, Val Loss: 0.063827
# Epoch [599/1000], Train Loss: 0.042587, Val Loss: 0.063759
# Epoch [600/1000], Train Loss: 0.042495, Val Loss: 0.063425
# Epoch [601/1000], Train Loss: 0.042341, Val Loss: 0.063190
# Epoch [602/1000], Train Loss: 0.042214, Val Loss: 0.063763
# Epoch [603/1000], Train Loss: 0.042239, Val Loss: 0.063359
# Epoch [604/1000], Train Loss: 0.042113, Val Loss: 0.064520
# Epoch [605/1000], Train Loss: 0.042454, Val Loss: 0.062713
# Epoch [606/1000], Train Loss: 0.042264, Val Loss: 0.062910
# Epoch [607/1000], Train Loss: 0.041799, Val Loss: 0.063284
# Epoch [608/1000], Train Loss: 0.042133, Val Loss: 0.062881
# Epoch [609/1000], Train Loss: 0.041943, Val Loss: 0.063893
# Epoch [610/1000], Train Loss: 0.042065, Val Loss: 0.063373
# Epoch [611/1000], Train Loss: 0.041814, Val Loss: 0.063647
# Epoch [612/1000], Train Loss: 0.042312, Val Loss: 0.062260
# Epoch [613/1000], Train Loss: 0.041740, Val Loss: 0.062844
# Epoch [614/1000], Train Loss: 0.041838, Val Loss: 0.062638
# Epoch [615/1000], Train Loss: 0.042020, Val Loss: 0.062364
# Epoch [616/1000], Train Loss: 0.041742, Val Loss: 0.062138
# Epoch [617/1000], Train Loss: 0.041505, Val Loss: 0.062920
# Epoch [618/1000], Train Loss: 0.041728, Val Loss: 0.062549
# Epoch [619/1000], Train Loss: 0.041786, Val Loss: 0.061985
# Epoch [620/1000], Train Loss: 0.041541, Val Loss: 0.061745
# Epoch [621/1000], Train Loss: 0.041386, Val Loss: 0.062635
# Epoch [622/1000], Train Loss: 0.041535, Val Loss: 0.062103
# Epoch [623/1000], Train Loss: 0.041347, Val Loss: 0.062608
# Epoch [624/1000], Train Loss: 0.041780, Val Loss: 0.060962
# Epoch [625/1000], Train Loss: 0.041264, Val Loss: 0.061931
# Epoch [626/1000], Train Loss: 0.041341, Val Loss: 0.061887
# Epoch [627/1000], Train Loss: 0.041534, Val Loss: 0.061671
# Epoch [628/1000], Train Loss: 0.041109, Val Loss: 0.061322
# Epoch [629/1000], Train Loss: 0.041164, Val Loss: 0.061756
# Epoch [630/1000], Train Loss: 0.041599, Val Loss: 0.060769
# Epoch [631/1000], Train Loss: 0.041111, Val Loss: 0.061894
# Epoch [632/1000], Train Loss: 0.041139, Val Loss: 0.061557
# Epoch [633/1000], Train Loss: 0.041208, Val Loss: 0.061281
# Epoch [634/1000], Train Loss: 0.041178, Val Loss: 0.061021
# Epoch [635/1000], Train Loss: 0.041000, Val Loss: 0.061966
# Epoch [636/1000], Train Loss: 0.041113, Val Loss: 0.061233
# Epoch [637/1000], Train Loss: 0.041010, Val Loss: 0.060749
# Epoch [638/1000], Train Loss: 0.041051, Val Loss: 0.060823
# Epoch [639/1000], Train Loss: 0.040960, Val Loss: 0.061800
# Epoch [640/1000], Train Loss: 0.040864, Val Loss: 0.060467
# Epoch [641/1000], Train Loss: 0.041209, Val Loss: 0.060594
# Epoch [642/1000], Train Loss: 0.040837, Val Loss: 0.060671
# Epoch [643/1000], Train Loss: 0.040619, Val Loss: 0.061132
# Epoch [644/1000], Train Loss: 0.041293, Val Loss: 0.060184
# Epoch [645/1000], Train Loss: 0.040661, Val Loss: 0.061284
# Epoch [646/1000], Train Loss: 0.040686, Val Loss: 0.060927
# Epoch [647/1000], Train Loss: 0.041138, Val Loss: 0.060038
# Epoch [648/1000], Train Loss: 0.040404, Val Loss: 0.060870
# Epoch [649/1000], Train Loss: 0.040869, Val Loss: 0.060916
# Epoch [650/1000], Train Loss: 0.040423, Val Loss: 0.060765
# Epoch [651/1000], Train Loss: 0.041055, Val Loss: 0.059953
# Epoch [652/1000], Train Loss: 0.040508, Val Loss: 0.061088
# Epoch [653/1000], Train Loss: 0.040754, Val Loss: 0.059934
# Epoch [654/1000], Train Loss: 0.040635, Val Loss: 0.060627
# Epoch [655/1000], Train Loss: 0.040241, Val Loss: 0.061040
# Epoch [656/1000], Train Loss: 0.040966, Val Loss: 0.060181
# Epoch [657/1000], Train Loss: 0.040314, Val Loss: 0.060454
# Epoch [658/1000], Train Loss: 0.040235, Val Loss: 0.060491
# Epoch [659/1000], Train Loss: 0.040920, Val Loss: 0.059775
# Epoch [660/1000], Train Loss: 0.040368, Val Loss: 0.060979
# Epoch [661/1000], Train Loss: 0.040390, Val Loss: 0.060363
# Epoch [662/1000], Train Loss: 0.040408, Val Loss: 0.060983
# Epoch [663/1000], Train Loss: 0.040550, Val Loss: 0.059793
# Epoch [664/1000], Train Loss: 0.040464, Val Loss: 0.060472
# Epoch [665/1000], Train Loss: 0.040083, Val Loss: 0.060629
# Epoch [666/1000], Train Loss: 0.040596, Val Loss: 0.059312
# Epoch [667/1000], Train Loss: 0.040410, Val Loss: 0.059943
# Epoch [668/1000], Train Loss: 0.040582, Val Loss: 0.060241
# Epoch [669/1000], Train Loss: 0.040272, Val Loss: 0.059776
# Epoch [670/1000], Train Loss: 0.040565, Val Loss: 0.060521
# Epoch [671/1000], Train Loss: 0.040169, Val Loss: 0.060164
# Epoch [672/1000], Train Loss: 0.040415, Val Loss: 0.059104
# Epoch [673/1000], Train Loss: 0.040192, Val Loss: 0.060755
# Epoch [674/1000], Train Loss: 0.040202, Val Loss: 0.059737
# Epoch [675/1000], Train Loss: 0.040587, Val Loss: 0.059433
# Epoch [676/1000], Train Loss: 0.039885, Val Loss: 0.060150
# Epoch [677/1000], Train Loss: 0.040490, Val Loss: 0.059473
# Epoch [678/1000], Train Loss: 0.039892, Val Loss: 0.059479
# Epoch [679/1000], Train Loss: 0.040337, Val Loss: 0.060141
# Epoch [680/1000], Train Loss: 0.039947, Val Loss: 0.059855
# Epoch [681/1000], Train Loss: 0.039922, Val Loss: 0.059283
# Epoch [682/1000], Train Loss: 0.040324, Val Loss: 0.059684
# Epoch [683/1000], Train Loss: 0.039840, Val Loss: 0.059400
# Epoch [684/1000], Train Loss: 0.040290, Val Loss: 0.059855
# Epoch [685/1000], Train Loss: 0.039818, Val Loss: 0.059489
# Epoch [686/1000], Train Loss: 0.039362, Val Loss: 0.059505
# Epoch [687/1000], Train Loss: 0.039841, Val Loss: 0.059153
# Epoch [688/1000], Train Loss: 0.039202, Val Loss: 0.059235
# Epoch [689/1000], Train Loss: 0.039807, Val Loss: 0.059027
# Epoch [690/1000], Train Loss: 0.039325, Val Loss: 0.059484
# Epoch [691/1000], Train Loss: 0.039801, Val Loss: 0.058266
# Epoch [692/1000], Train Loss: 0.039175, Val Loss: 0.058592
# Epoch [693/1000], Train Loss: 0.039366, Val Loss: 0.059579
# Epoch [694/1000], Train Loss: 0.039699, Val Loss: 0.058394
# Epoch [695/1000], Train Loss: 0.039289, Val Loss: 0.058372
# Epoch [696/1000], Train Loss: 0.039481, Val Loss: 0.059160
# Epoch [697/1000], Train Loss: 0.039027, Val Loss: 0.059048
# Epoch [698/1000], Train Loss: 0.039000, Val Loss: 0.058603
# Epoch [699/1000], Train Loss: 0.039422, Val Loss: 0.058577
# Epoch [700/1000], Train Loss: 0.038986, Val Loss: 0.058648
# Epoch [701/1000], Train Loss: 0.039428, Val Loss: 0.057835
# Epoch [702/1000], Train Loss: 0.038791, Val Loss: 0.058583
# Epoch [703/1000], Train Loss: 0.039115, Val Loss: 0.058809
# Epoch [704/1000], Train Loss: 0.039107, Val Loss: 0.058067
# Epoch [705/1000], Train Loss: 0.038970, Val Loss: 0.058898
# Epoch [706/1000], Train Loss: 0.039134, Val Loss: 0.057994
# Epoch [707/1000], Train Loss: 0.038725, Val Loss: 0.058044
# Epoch [708/1000], Train Loss: 0.038938, Val Loss: 0.058340
# Epoch [709/1000], Train Loss: 0.039001, Val Loss: 0.058068
# Epoch [710/1000], Train Loss: 0.038840, Val Loss: 0.058072
# Epoch [711/1000], Train Loss: 0.038854, Val Loss: 0.058135
# Epoch [712/1000], Train Loss: 0.038840, Val Loss: 0.057562
# Epoch [713/1000], Train Loss: 0.038923, Val Loss: 0.057520
# Epoch [714/1000], Train Loss: 0.038644, Val Loss: 0.058337
# Epoch [715/1000], Train Loss: 0.038595, Val Loss: 0.058019
# Epoch [716/1000], Train Loss: 0.038963, Val Loss: 0.057388
# Epoch [717/1000], Train Loss: 0.038387, Val Loss: 0.057765
# Epoch [718/1000], Train Loss: 0.038969, Val Loss: 0.057388
# Epoch [719/1000], Train Loss: 0.038291, Val Loss: 0.058123
# Epoch [720/1000], Train Loss: 0.039017, Val Loss: 0.057640
# Epoch [721/1000], Train Loss: 0.038382, Val Loss: 0.057650
# Epoch [722/1000], Train Loss: 0.038562, Val Loss: 0.057837
# Epoch [723/1000], Train Loss: 0.038630, Val Loss: 0.057928
# Epoch [724/1000], Train Loss: 0.038116, Val Loss: 0.058012
# Epoch [725/1000], Train Loss: 0.038685, Val Loss: 0.058270
# Epoch [726/1000], Train Loss: 0.038848, Val Loss: 0.058530
# Epoch [727/1000], Train Loss: 0.038723, Val Loss: 0.057614
# Epoch [728/1000], Train Loss: 0.038213, Val Loss: 0.057580
# Epoch [729/1000], Train Loss: 0.038391, Val Loss: 0.057651
# Epoch [730/1000], Train Loss: 0.038328, Val Loss: 0.057512
# Epoch [731/1000], Train Loss: 0.038412, Val Loss: 0.056904
# Epoch [732/1000], Train Loss: 0.038210, Val Loss: 0.058017
# Epoch [733/1000], Train Loss: 0.038191, Val Loss: 0.057316
# Epoch [734/1000], Train Loss: 0.038102, Val Loss: 0.056984
# Epoch [735/1000], Train Loss: 0.038449, Val Loss: 0.057479
# Epoch [736/1000], Train Loss: 0.037996, Val Loss: 0.057456
# Epoch [737/1000], Train Loss: 0.038326, Val Loss: 0.057024
# Epoch [738/1000], Train Loss: 0.037702, Val Loss: 0.058342
# Epoch [739/1000], Train Loss: 0.038652, Val Loss: 0.057607
# Epoch [740/1000], Train Loss: 0.038346, Val Loss: 0.057950
# Epoch [741/1000], Train Loss: 0.038371, Val Loss: 0.057119
# Epoch [742/1000], Train Loss: 0.038311, Val Loss: 0.056798
# Epoch [743/1000], Train Loss: 0.038101, Val Loss: 0.057630
# Epoch [744/1000], Train Loss: 0.038049, Val Loss: 0.057066
# Epoch [745/1000], Train Loss: 0.038355, Val Loss: 0.057335
# Epoch [746/1000], Train Loss: 0.038182, Val Loss: 0.057073
# Epoch [747/1000], Train Loss: 0.038147, Val Loss: 0.057721
# Epoch [748/1000], Train Loss: 0.037994, Val Loss: 0.057195
# Epoch [749/1000], Train Loss: 0.038137, Val Loss: 0.056813
# Epoch [750/1000], Train Loss: 0.037798, Val Loss: 0.057418
# Epoch [751/1000], Train Loss: 0.038329, Val Loss: 0.056839
# Epoch [752/1000], Train Loss: 0.038041, Val Loss: 0.057422
# Epoch [753/1000], Train Loss: 0.037821, Val Loss: 0.057209
# Epoch [754/1000], Train Loss: 0.038196, Val Loss: 0.057420
# Epoch [755/1000], Train Loss: 0.038111, Val Loss: 0.056871
# Epoch [756/1000], Train Loss: 0.037912, Val Loss: 0.056737
# Epoch [757/1000], Train Loss: 0.037473, Val Loss: 0.057143
# Epoch [758/1000], Train Loss: 0.037735, Val Loss: 0.056764
# Epoch [759/1000], Train Loss: 0.038039, Val Loss: 0.057058
# Epoch [760/1000], Train Loss: 0.037644, Val Loss: 0.057009
# Epoch [761/1000], Train Loss: 0.037663, Val Loss: 0.056498
# Epoch [762/1000], Train Loss: 0.037943, Val Loss: 0.056922
# Epoch [763/1000], Train Loss: 0.037796, Val Loss: 0.056619
# Epoch [764/1000], Train Loss: 0.037533, Val Loss: 0.057238
# Epoch [765/1000], Train Loss: 0.038025, Val Loss: 0.056557
# Epoch [766/1000], Train Loss: 0.036984, Val Loss: 0.057140
# Epoch [767/1000], Train Loss: 0.037933, Val Loss: 0.057592
# Epoch [768/1000], Train Loss: 0.037796, Val Loss: 0.056525
# Epoch [769/1000], Train Loss: 0.037470, Val Loss: 0.056387
# Epoch [770/1000], Train Loss: 0.037892, Val Loss: 0.056500
# Epoch [771/1000], Train Loss: 0.037666, Val Loss: 0.056450
# Epoch [772/1000], Train Loss: 0.037602, Val Loss: 0.056806
# Epoch [773/1000], Train Loss: 0.037871, Val Loss: 0.056212
# Epoch [774/1000], Train Loss: 0.036848, Val Loss: 0.056900
# Epoch [775/1000], Train Loss: 0.037581, Val Loss: 0.056461
# Epoch [776/1000], Train Loss: 0.037501, Val Loss: 0.056869
# Epoch [777/1000], Train Loss: 0.037820, Val Loss: 0.056508
# Epoch [778/1000], Train Loss: 0.037428, Val Loss: 0.056441
# Epoch [779/1000], Train Loss: 0.037395, Val Loss: 0.056365
# Epoch [780/1000], Train Loss: 0.037165, Val Loss: 0.056099
# Epoch [781/1000], Train Loss: 0.037274, Val Loss: 0.056584
# Epoch [782/1000], Train Loss: 0.037623, Val Loss: 0.056719
# Epoch [783/1000], Train Loss: 0.037457, Val Loss: 0.056375
# Epoch [784/1000], Train Loss: 0.037322, Val Loss: 0.056657
# Epoch [785/1000], Train Loss: 0.037215, Val Loss: 0.056282
# Epoch [786/1000], Train Loss: 0.037258, Val Loss: 0.055758
# Epoch [787/1000], Train Loss: 0.037026, Val Loss: 0.055851
# Epoch [788/1000], Train Loss: 0.037277, Val Loss: 0.055947
# Epoch [789/1000], Train Loss: 0.037171, Val Loss: 0.056621
# Epoch [790/1000], Train Loss: 0.036927, Val Loss: 0.055832
# Epoch [791/1000], Train Loss: 0.036863, Val Loss: 0.056745
# Epoch [792/1000], Train Loss: 0.037220, Val Loss: 0.056389
# Epoch [793/1000], Train Loss: 0.036923, Val Loss: 0.055826
# Epoch [794/1000], Train Loss: 0.036866, Val Loss: 0.056282
# Epoch [795/1000], Train Loss: 0.037332, Val Loss: 0.056016
# Epoch [796/1000], Train Loss: 0.037167, Val Loss: 0.056563
# Epoch [797/1000], Train Loss: 0.037395, Val Loss: 0.055550
# Epoch [798/1000], Train Loss: 0.036666, Val Loss: 0.055337
# Epoch [799/1000], Train Loss: 0.036547, Val Loss: 0.055998
# Epoch [800/1000], Train Loss: 0.037295, Val Loss: 0.056409
# Epoch [801/1000], Train Loss: 0.037158, Val Loss: 0.055604
# Epoch [802/1000], Train Loss: 0.036754, Val Loss: 0.055654
# Epoch [803/1000], Train Loss: 0.037085, Val Loss: 0.056190
# Epoch [804/1000], Train Loss: 0.036711, Val Loss: 0.055814
# Epoch [805/1000], Train Loss: 0.036817, Val Loss: 0.056107
# Epoch [806/1000], Train Loss: 0.037120, Val Loss: 0.055601
# Epoch [807/1000], Train Loss: 0.036496, Val Loss: 0.055518
# Epoch [808/1000], Train Loss: 0.036762, Val Loss: 0.056373
# Epoch [809/1000], Train Loss: 0.036741, Val Loss: 0.055729
# Epoch [810/1000], Train Loss: 0.036898, Val Loss: 0.056206
# Epoch [811/1000], Train Loss: 0.036751, Val Loss: 0.056365
# Epoch [812/1000], Train Loss: 0.036720, Val Loss: 0.055112
# Epoch [813/1000], Train Loss: 0.036296, Val Loss: 0.055295
# Epoch [814/1000], Train Loss: 0.036765, Val Loss: 0.055911
# Epoch [815/1000], Train Loss: 0.036472, Val Loss: 0.055442
# Epoch [816/1000], Train Loss: 0.036198, Val Loss: 0.055562
# Epoch [817/1000], Train Loss: 0.036968, Val Loss: 0.055712
# Epoch [818/1000], Train Loss: 0.036590, Val Loss: 0.055766
# Epoch [819/1000], Train Loss: 0.036696, Val Loss: 0.054952
# Epoch [820/1000], Train Loss: 0.036631, Val Loss: 0.054841
# Epoch [821/1000], Train Loss: 0.036580, Val Loss: 0.054806
# Epoch [822/1000], Train Loss: 0.036085, Val Loss: 0.055598
# Epoch [823/1000], Train Loss: 0.036437, Val Loss: 0.055085
# Epoch [824/1000], Train Loss: 0.036352, Val Loss: 0.055353
# Epoch [825/1000], Train Loss: 0.036388, Val Loss: 0.055003
# Epoch [826/1000], Train Loss: 0.036276, Val Loss: 0.055126
# Epoch [827/1000], Train Loss: 0.035977, Val Loss: 0.055732
# Epoch [828/1000], Train Loss: 0.036435, Val Loss: 0.055120
# Epoch [829/1000], Train Loss: 0.036308, Val Loss: 0.054959
# Epoch [830/1000], Train Loss: 0.036109, Val Loss: 0.054390
# Epoch [831/1000], Train Loss: 0.036254, Val Loss: 0.054999
# Epoch [832/1000], Train Loss: 0.036029, Val Loss: 0.053942
# Epoch [833/1000], Train Loss: 0.036120, Val Loss: 0.054188
# Epoch [834/1000], Train Loss: 0.035961, Val Loss: 0.054258
# Epoch [835/1000], Train Loss: 0.036168, Val Loss: 0.054737
# Epoch [836/1000], Train Loss: 0.036179, Val Loss: 0.053905
# Epoch [837/1000], Train Loss: 0.035939, Val Loss: 0.054337
# Epoch [838/1000], Train Loss: 0.035967, Val Loss: 0.054733
# Epoch [839/1000], Train Loss: 0.036493, Val Loss: 0.054423
# Epoch [840/1000], Train Loss: 0.035848, Val Loss: 0.054005
# Epoch [841/1000], Train Loss: 0.036205, Val Loss: 0.054093
# Epoch [842/1000], Train Loss: 0.035836, Val Loss: 0.055119
# Epoch [843/1000], Train Loss: 0.036244, Val Loss: 0.054261
# Epoch [844/1000], Train Loss: 0.036015, Val Loss: 0.054640
# Epoch [845/1000], Train Loss: 0.035994, Val Loss: 0.053785
# Epoch [846/1000], Train Loss: 0.035321, Val Loss: 0.054690
# Epoch [847/1000], Train Loss: 0.036297, Val Loss: 0.054698
# Epoch [848/1000], Train Loss: 0.035784, Val Loss: 0.054059
# Epoch [849/1000], Train Loss: 0.036069, Val Loss: 0.053924
# Epoch [850/1000], Train Loss: 0.035448, Val Loss: 0.053487
# Epoch [851/1000], Train Loss: 0.035866, Val Loss: 0.054639
# Epoch [852/1000], Train Loss: 0.035793, Val Loss: 0.054944
# Epoch [853/1000], Train Loss: 0.035905, Val Loss: 0.053883
# Epoch [854/1000], Train Loss: 0.035830, Val Loss: 0.053780
# Epoch [855/1000], Train Loss: 0.035821, Val Loss: 0.053194
# Epoch [856/1000], Train Loss: 0.035387, Val Loss: 0.053952
# Epoch [857/1000], Train Loss: 0.036006, Val Loss: 0.054332
# Epoch [858/1000], Train Loss: 0.035476, Val Loss: 0.053492
# Epoch [859/1000], Train Loss: 0.035572, Val Loss: 0.054136
# Epoch [860/1000], Train Loss: 0.035651, Val Loss: 0.054189
# Epoch [861/1000], Train Loss: 0.035546, Val Loss: 0.054238
# Epoch [862/1000], Train Loss: 0.035954, Val Loss: 0.053976
# Epoch [863/1000], Train Loss: 0.035271, Val Loss: 0.053607
# Epoch [864/1000], Train Loss: 0.035837, Val Loss: 0.053972
# Epoch [865/1000], Train Loss: 0.035051, Val Loss: 0.054309
# Epoch [866/1000], Train Loss: 0.035911, Val Loss: 0.054016
# Epoch [867/1000], Train Loss: 0.035318, Val Loss: 0.053448
# Epoch [868/1000], Train Loss: 0.035521, Val Loss: 0.053300
# Epoch [869/1000], Train Loss: 0.035130, Val Loss: 0.054155
# Epoch [870/1000], Train Loss: 0.035775, Val Loss: 0.052839
# Epoch [871/1000], Train Loss: 0.035432, Val Loss: 0.053128
# Epoch [872/1000], Train Loss: 0.035014, Val Loss: 0.053372
# Epoch [873/1000], Train Loss: 0.035263, Val Loss: 0.052853
# Epoch [874/1000], Train Loss: 0.035223, Val Loss: 0.053233
# Epoch [875/1000], Train Loss: 0.035352, Val Loss: 0.053435
# Epoch [876/1000], Train Loss: 0.035057, Val Loss: 0.052749
# Epoch [877/1000], Train Loss: 0.035339, Val Loss: 0.053543
# Epoch [878/1000], Train Loss: 0.035332, Val Loss: 0.053286
# Epoch [879/1000], Train Loss: 0.035298, Val Loss: 0.052434
# Epoch [880/1000], Train Loss: 0.035273, Val Loss: 0.053162
# Epoch [881/1000], Train Loss: 0.035275, Val Loss: 0.053099
# Epoch [882/1000], Train Loss: 0.035538, Val Loss: 0.053002
# Epoch [883/1000], Train Loss: 0.034876, Val Loss: 0.052539
# Epoch [884/1000], Train Loss: 0.034848, Val Loss: 0.052920
# Epoch [885/1000], Train Loss: 0.035552, Val Loss: 0.052886
# Epoch [886/1000], Train Loss: 0.034655, Val Loss: 0.052637
# Epoch [887/1000], Train Loss: 0.035414, Val Loss: 0.052842
# Epoch [888/1000], Train Loss: 0.035165, Val Loss: 0.052194
# Epoch [889/1000], Train Loss: 0.034650, Val Loss: 0.052962
# Epoch [890/1000], Train Loss: 0.035141, Val Loss: 0.052264
# Epoch [891/1000], Train Loss: 0.034414, Val Loss: 0.053020
# Epoch [892/1000], Train Loss: 0.035480, Val Loss: 0.052851
# Epoch [893/1000], Train Loss: 0.034778, Val Loss: 0.052142
# Epoch [894/1000], Train Loss: 0.034563, Val Loss: 0.052909
# Epoch [895/1000], Train Loss: 0.035059, Val Loss: 0.053070
# Epoch [896/1000], Train Loss: 0.035037, Val Loss: 0.052269
# Epoch [897/1000], Train Loss: 0.034581, Val Loss: 0.052820
# Epoch [898/1000], Train Loss: 0.035276, Val Loss: 0.052589
# Epoch [899/1000], Train Loss: 0.034498, Val Loss: 0.052318
# Epoch [900/1000], Train Loss: 0.034895, Val Loss: 0.052514
# Epoch [901/1000], Train Loss: 0.034910, Val Loss: 0.051907
# Epoch [902/1000], Train Loss: 0.034227, Val Loss: 0.052745
# Epoch [903/1000], Train Loss: 0.035290, Val Loss: 0.052570
# Epoch [904/1000], Train Loss: 0.035158, Val Loss: 0.052615
# Epoch [905/1000], Train Loss: 0.034347, Val Loss: 0.052177
# Epoch [906/1000], Train Loss: 0.035096, Val Loss: 0.052515
# Epoch [907/1000], Train Loss: 0.034478, Val Loss: 0.051914
# Epoch [908/1000], Train Loss: 0.034319, Val Loss: 0.052699
# Epoch [909/1000], Train Loss: 0.035127, Val Loss: 0.052470
# Epoch [910/1000], Train Loss: 0.034413, Val Loss: 0.051725
# Epoch [911/1000], Train Loss: 0.034234, Val Loss: 0.052407
# Epoch [912/1000], Train Loss: 0.035051, Val Loss: 0.052625
# Epoch [913/1000], Train Loss: 0.034380, Val Loss: 0.051891
# Epoch [914/1000], Train Loss: 0.034176, Val Loss: 0.052525
# Epoch [915/1000], Train Loss: 0.035038, Val Loss: 0.052343
# Epoch [916/1000], Train Loss: 0.034301, Val Loss: 0.051627
# Epoch [917/1000], Train Loss: 0.034173, Val Loss: 0.052489
# Epoch [918/1000], Train Loss: 0.034966, Val Loss: 0.052229
# Epoch [919/1000], Train Loss: 0.033949, Val Loss: 0.051882
# Epoch [920/1000], Train Loss: 0.034551, Val Loss: 0.052151
# Epoch [921/1000], Train Loss: 0.034448, Val Loss: 0.052060
# Epoch [922/1000], Train Loss: 0.034124, Val Loss: 0.052034
# Epoch [923/1000], Train Loss: 0.034573, Val Loss: 0.052015
# Epoch [924/1000], Train Loss: 0.034780, Val Loss: 0.051963
# Epoch [925/1000], Train Loss: 0.034088, Val Loss: 0.052092
# Epoch [926/1000], Train Loss: 0.034123, Val Loss: 0.051897
# Epoch [927/1000], Train Loss: 0.034374, Val Loss: 0.051436
# Epoch [928/1000], Train Loss: 0.034198, Val Loss: 0.052073
# Epoch [929/1000], Train Loss: 0.034310, Val Loss: 0.052309
# Epoch [930/1000], Train Loss: 0.034163, Val Loss: 0.052390
# Epoch [931/1000], Train Loss: 0.034402, Val Loss: 0.051572
# Epoch [932/1000], Train Loss: 0.034389, Val Loss: 0.051711
# Epoch [933/1000], Train Loss: 0.033867, Val Loss: 0.052323
# Epoch [934/1000], Train Loss: 0.034718, Val Loss: 0.051886
# Epoch [935/1000], Train Loss: 0.033821, Val Loss: 0.051731
# Epoch [936/1000], Train Loss: 0.034311, Val Loss: 0.051665
# Epoch [937/1000], Train Loss: 0.034519, Val Loss: 0.051841
# Epoch [938/1000], Train Loss: 0.033661, Val Loss: 0.051835
# Epoch [939/1000], Train Loss: 0.034193, Val Loss: 0.051675
# Epoch [940/1000], Train Loss: 0.033730, Val Loss: 0.051743
# Epoch [941/1000], Train Loss: 0.033960, Val Loss: 0.051730
# Epoch [942/1000], Train Loss: 0.034496, Val Loss: 0.051361
# Epoch [943/1000], Train Loss: 0.033748, Val Loss: 0.052124
# Epoch [944/1000], Train Loss: 0.034483, Val Loss: 0.051930
# Epoch [945/1000], Train Loss: 0.033764, Val Loss: 0.051267
# Epoch [946/1000], Train Loss: 0.033791, Val Loss: 0.052079
# Epoch [947/1000], Train Loss: 0.034438, Val Loss: 0.051361
# Epoch [948/1000], Train Loss: 0.033567, Val Loss: 0.051742
# Epoch [949/1000], Train Loss: 0.034489, Val Loss: 0.051477
# Epoch [950/1000], Train Loss: 0.033647, Val Loss: 0.050923
# Epoch [951/1000], Train Loss: 0.033596, Val Loss: 0.051836
# Epoch [952/1000], Train Loss: 0.034360, Val Loss: 0.051350
# Epoch [953/1000], Train Loss: 0.033457, Val Loss: 0.052018
# Epoch [954/1000], Train Loss: 0.033955, Val Loss: 0.051106
# Epoch [955/1000], Train Loss: 0.033912, Val Loss: 0.051381
# Epoch [956/1000], Train Loss: 0.033473, Val Loss: 0.052036
# Epoch [957/1000], Train Loss: 0.034298, Val Loss: 0.051299
# Epoch [958/1000], Train Loss: 0.033403, Val Loss: 0.051473
# Epoch [959/1000], Train Loss: 0.034320, Val Loss: 0.051454
# Epoch [960/1000], Train Loss: 0.033480, Val Loss: 0.050920
# Epoch [961/1000], Train Loss: 0.033798, Val Loss: 0.051450
# Epoch [962/1000], Train Loss: 0.033748, Val Loss: 0.051277
# Epoch [963/1000], Train Loss: 0.033765, Val Loss: 0.051205
# Epoch [964/1000], Train Loss: 0.033367, Val Loss: 0.051899
# Epoch [965/1000], Train Loss: 0.034157, Val Loss: 0.051197
# Epoch [966/1000], Train Loss: 0.033362, Val Loss: 0.052154
# Epoch [967/1000], Train Loss: 0.034086, Val Loss: 0.051418
# Epoch [968/1000], Train Loss: 0.033662, Val Loss: 0.051090
# Epoch [969/1000], Train Loss: 0.033442, Val Loss: 0.051138
# Epoch [970/1000], Train Loss: 0.033760, Val Loss: 0.051554
# Epoch [971/1000], Train Loss: 0.033945, Val Loss: 0.051214
# Epoch [972/1000], Train Loss: 0.033315, Val Loss: 0.051087
# Epoch [973/1000], Train Loss: 0.033248, Val Loss: 0.051000
# Epoch [974/1000], Train Loss: 0.033435, Val Loss: 0.050767
# Epoch [975/1000], Train Loss: 0.033528, Val Loss: 0.050927
# Epoch [976/1000], Train Loss: 0.033444, Val Loss: 0.051262
# Epoch [977/1000], Train Loss: 0.033913, Val Loss: 0.051137
# Epoch [978/1000], Train Loss: 0.033233, Val Loss: 0.051365
# Epoch [979/1000], Train Loss: 0.033771, Val Loss: 0.051299
# Epoch [980/1000], Train Loss: 0.033460, Val Loss: 0.050642
# Epoch [981/1000], Train Loss: 0.033111, Val Loss: 0.051481
# Epoch [982/1000], Train Loss: 0.033519, Val Loss: 0.051056
# Epoch [983/1000], Train Loss: 0.033047, Val Loss: 0.051369
# Epoch [984/1000], Train Loss: 0.033491, Val Loss: 0.051103
# Epoch [985/1000], Train Loss: 0.033755, Val Loss: 0.051036
# Epoch [986/1000], Train Loss: 0.033109, Val Loss: 0.051098
# Epoch [987/1000], Train Loss: 0.033041, Val Loss: 0.050742
# Epoch [988/1000], Train Loss: 0.033244, Val Loss: 0.050556
# Epoch [989/1000], Train Loss: 0.033314, Val Loss: 0.050513
# Epoch [990/1000], Train Loss: 0.033075, Val Loss: 0.051098
# Epoch [991/1000], Train Loss: 0.033254, Val Loss: 0.051120
# Epoch [992/1000], Train Loss: 0.033676, Val Loss: 0.050789
# Epoch [993/1000], Train Loss: 0.033010, Val Loss: 0.051188
# Epoch [994/1000], Train Loss: 0.033615, Val Loss: 0.050829
# Epoch [995/1000], Train Loss: 0.033186, Val Loss: 0.050458
# Epoch [996/1000], Train Loss: 0.032774, Val Loss: 0.050848
# Epoch [997/1000], Train Loss: 0.033261, Val Loss: 0.050798
# Epoch [998/1000], Train Loss: 0.032993, Val Loss: 0.051156
# Epoch [999/1000], Train Loss: 0.033171, Val Loss: 0.050626
# Epoch [1000/1000], Train Loss: 0.032705, Val Loss: 0.050293

# %%
# Plot loss curves
plt.figure(figsize=(8, 5))
plt.plot(range(1, num_epochs + 1), train_losses, label="Training Loss", marker='o')
plt.plot(range(1, num_epochs + 1), val_losses, label="Validation Loss", marker='s')
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss Over Epochs")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Set model to evaluation mode
nn_model.eval()

# No gradient computation during evaluation
with torch.no_grad():
    test_predictions = nn_model(test_set)  # Get model predictions
    mse_test = loss_fn(test_targets, test_predictions)

# Print MSE
print(f"Test MSE: {mse_test:.6f}")
# Out:
# Test MSE: 0.033071

# %%
# Plot True vs. Predicted values
plt.figure(figsize=(6, 6))
plt.scatter(test_targets[:, 0], test_predictions[:, 0], label="Y1", alpha=0.7)
plt.scatter(test_targets[:, 1], test_predictions[:, 1], label="Y2", alpha=0.7)
plt.plot([test_targets.min(), test_targets.max()], [test_targets.min(), test_targets.max()], "k--")  # y=x line
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("True vs. Predicted Values on Test Set")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# **(d)** Let
#
# $$
# m(V_{\max}, K_m, \alpha, \beta) := e^{\phi(V_{\max}, K_m, \alpha, \beta)}
# $$
#
# be the model surrogate for $Y_1$ and $Y_2$. Repeat the sensitivity analysis at point (a) using the surrogate model rather than the ODE solver. Are the results comparable? How much faster is the neural network model?

# %%
def surrogate_model(X):
  Y1, Y2 = nn_model(X)
  return torch.exp(outputs)

# %%
def sobol_indices_surrogate_Y1(surr_model, p, xmin, xmax, N):
  A, B, C = saltelli_ABC(N, p, xmin, xmax)

  A,B,C = torch.Tensor(A).float(), torch.Tensor(B).float(), torch.Tensor(C).float()

  yA = surr_model(A)[:, 0].detach().numpy()
  yB = surr_model(B)[:, 0].detach().numpy()
  yC = [surr_model(Ci)[:, 0].detach().numpy() for Ci in C]

  Si, STi = saltelli_Si(yA, yB, yC)

  return clamp01(Si), clamp01(STi)

# %%
def sobol_indices_surrogate_Y2(surr_model, p, xmin, xmax, N):
  A, B, C = saltelli_ABC(N, p, xmin, xmax)

  A,B,C = torch.Tensor(A).float(), torch.Tensor(B).float(), torch.Tensor(C).float()

  yA = surr_model(A)[:, 1].detach().numpy()
  yB = surr_model(B)[:, 1].detach().numpy()
  yC = [surr_model(Ci)[:, 1].detach().numpy() for Ci in C]

  Si, STi = saltelli_Si(yA, yB, yC)

  return clamp01(Si), clamp01(STi)

# %%
Si, STi = sobol_indices_surrogate_Y1(surrogate_model, p = 4, xmin = np.array([5, 5, 0.1, 0.1]), xmax = np.array([10, 10, 0.5, 0.5]), N = 1024)
pd.DataFrame({'Main effect':Si, 'Total effect':STi}, index = ["Vmax", "Km", "alpha", "beta"])
# Out:
#        Main effect  Total effect
# Vmax      0.338103      0.796904
# Km        0.189144      0.635179
# alpha     0.006180      0.001328
# beta      0.006284      0.006889

# %%
Si, STi = sobol_indices_surrogate_Y2(surrogate_model, p = 4, xmin = np.array([5, 5, 0.1, 0.1]), xmax = np.array([10, 10, 0.5, 0.5]), N = 1024)
pd.DataFrame({'Main effect':Si, 'Total effect':STi}, index = ["Vmax", "Km", "alpha", "beta"])
# Out:
#        Main effect  Total effect
# Vmax      0.011762      0.052773
# Km        0.001700      0.027265
# alpha     0.352140      0.362533
# beta      0.599012      0.626398
